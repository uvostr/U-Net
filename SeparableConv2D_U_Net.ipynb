# %%
import speedup
import tensorflow as tf
import numpy as np
import tensorflow as tf
import random
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)

# %%
def double_conv_block(x, n_filters):
   x = tf.keras.layers.Conv2D(n_filters, (3, 3), activation = "relu", kernel_initializer = "he_normal", padding="same")(x)
   x = tf.keras.layers.BatchNormalization()(x)
   x = tf.keras.layers.SeparableConv2D(n_filters, (3, 3), activation = "relu", kernel_initializer = "he_normal", padding="same")(x)
   x = tf.keras.layers.BatchNormalization()(x)
   return x

# %%
def downsample_block(x, n_filters):
   f = double_conv_block(x, n_filters)
   p = tf.keras.layers.MaxPool2D((2, 2))(f)
   return f, p

# %%
def upsample_block(x, conv_features, n_filters):
   x = tf.keras.layers.Conv2DTranspose(n_filters, (3, 3), (2, 2), padding="same")(x)
   x = tf.keras.layers.concatenate([x, conv_features])
   x = double_conv_block(x, n_filters)
   return x

# %%
imageSize = 512
m = 3

def constructModel():
    inputs = tf.keras.Input(shape=(imageSize, imageSize, m))
    f1, p1 = downsample_block(inputs, 64)
    f2, p2 = downsample_block(p1, 128)
    f3, p3 = downsample_block(p2, 256)
    f4, p4 = downsample_block(p3, 512)
    

    bottleneck = double_conv_block(p4, 1024)

    u6 = upsample_block(bottleneck, f4, 512)
    u7 = upsample_block(u6, f3, 256)
    u8 = upsample_block(u7, f2, 128)
    u9 = upsample_block(u8, f1, 64)
    outputs = tf.keras.layers.Conv2D(3, (1, 1), activation='sigmoid', padding = "same")(u9)

    return tf.keras.Model(inputs, outputs, name="U-Net")

# %%
model_instance = constructModel()
model_instance.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  1792        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  separable_conv2d_9 (SeparableC  (None, 512, 512, 64  4736       ['batch_normalization_9[0][0]']
#  onv2D)                         )
#
#  batch_normalization_10 (BatchN  (None, 512, 512, 64  256        ['separable_conv2d_9[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 64  0          ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  batch_normalization_11 (BatchN  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  ormalization)                  8)
#
#  separable_conv2d_10 (Separable  (None, 256, 256, 12  17664      ['batch_normalization_11[0][0]']
#  Conv2D)                        8)
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 12  512        ['separable_conv2d_10[0][0]']
#  ormalization)                  8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 12  0          ['batch_normalization_12[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_5[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_3[0][0]']
#  ormalization)                  6)
#
#  separable_conv2d_11 (Separable  (None, 128, 128, 25  68096      ['batch_normalization_13[0][0]']
#  Conv2D)                        6)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 25  1024       ['separable_conv2d_11[0][0]']
#  ormalization)                  6)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 256)  0          ['batch_normalization_14[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_4[0][0]']
#  ormalization)
#
#  separable_conv2d_12 (Separable  (None, 64, 64, 512)  267264     ['batch_normalization_15[0][0]']
#  Conv2D)
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 512)  2048       ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 512)  0          ['batch_normalization_16[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_5[0][0]']
#  ormalization)                  )
#
#  separable_conv2d_13 (Separable  (None, 32, 32, 1024  1058816    ['batch_normalization_17[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 1024  4096       ['separable_conv2d_13[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 512)  4719104    ['batch_normalization_18[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'batch_normalization_16[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  ormalization)
#
#  separable_conv2d_14 (Separable  (None, 64, 64, 512)  267264     ['batch_normalization_19[0][0]']
#  Conv2D)
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 512)  2048       ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 25  1179904    ['batch_normalization_20[0][0]']
#  spose)                         6)
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_5[0][0]',
#                                 2)                                'batch_normalization_14[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 25  1179904     ['concatenate_5[0][0]']
#                                 6)
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 25  1024       ['conv2d_7[0][0]']
#  ormalization)                  6)
#
#  separable_conv2d_15 (Separable  (None, 128, 128, 25  68096      ['batch_normalization_21[0][0]']
#  Conv2D)                        6)
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 25  1024       ['separable_conv2d_15[0][0]']
#  ormalization)                  6)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 12  295040     ['batch_normalization_22[0][0]']
#  spose)                         8)
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'batch_normalization_12[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 12  295040      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_23 (BatchN  (None, 256, 256, 12  512        ['conv2d_8[0][0]']
#  ormalization)                  8)
#
#  separable_conv2d_16 (Separable  (None, 256, 256, 12  17664      ['batch_normalization_23[0][0]']
#  Conv2D)                        8)
#
#  batch_normalization_24 (BatchN  (None, 256, 256, 12  512        ['separable_conv2d_16[0][0]']
#  ormalization)                  8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 64  73792      ['batch_normalization_24[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'batch_normalization_10[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 512, 512, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 512, 512, 64  256        ['conv2d_9[0][0]']
#  ormalization)                  )
#
#  separable_conv2d_17 (Separable  (None, 512, 512, 64  4736       ['batch_normalization_25[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_26 (BatchN  (None, 512, 512, 64  256        ['separable_conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_10 (Conv2D)             (None, 512, 512, 3)  195         ['batch_normalization_26[0][0]']
#
# ==================================================================================================
# Total params: 20,604,355
# Trainable params: 20,592,579
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
image_path = '/content/drive/MyDrive/source2'
models_path = '/content/drive/MyDrive/models/'

# %%
import itertools
import tensorflow as tf
from speedup import generate_out_images3
import numpy as np
from random import randint, uniform
import imageio
import time


source_num = 2799
dim = 512
stationary_defocus = 0.05


def gen():
    while True:
        layer1_number = randint(0, source_num)
        layer2_number = randint(0, source_num)
        layer3_number = randint(0, source_num)

        src1 = imageio.imread(image_path + '/image' + str(layer1_number).zfill(4) + '.png')
        src2 = imageio.imread(image_path + '/image' + str(layer2_number).zfill(4) + '.png')
        src3 = imageio.imread(image_path + '/image' + str(layer3_number).zfill(4) + '.png')
        src = np.zeros((dim, dim, m), np.double)
        src[:, :, 0] = src1[:, :, 0]
        src[:, :, 1] = src2[:, :, 0]
        src[:, :, 2] = src3[:, :, 0]
        src = src - np.amin(src)
        src = src / np.amax(src)

        w = uniform(0.05, 0.5) 
        
        a_10 = uniform(-1e3, 1e3)
        a_01 = uniform(-1e3, 1e3)
        b_20 = uniform(1, 1.5)
        b_11 = uniform(-0.1, 0.1)
        b_02 = uniform(1, 1.5)
        c_30 = uniform(-1.5e-6, 1.5e-6)
        c_21 = uniform(-2e-6, 2e-6)
        c_12 = uniform(-2e-6, 2e-6)
        c_03 = uniform(-1.5e-6, 1.5e-6)

        out = generate_out_images3(dim, m, w, stationary_defocus, a_10, a_01, b_20, b_11, b_02, c_30, c_21, c_12, c_03, src)[1]

        out = out / np.amax(out)

        src[src > 0] = 1.

        yield (out, src)


tr_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .batch(batch_size=2).prefetch(buffer_size=8)

val_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .take(count=128).cache().batch(batch_size=2)


opt = tf.keras.optimizers.Adam()

save_best_callback = tf.keras.callbacks.ModelCheckpoint(models_path + 'bestmodel_SeparableConv2D_U_Net.hdf5',
                                                        save_weights_only=True,save_best_only=True, verbose=True)
csv_logger_callback = tf.keras.callbacks.CSVLogger(models_path + 'log_SeparableConv2D_U_Net.csv')
lr_reduce_callback = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, min_delta=5e-4, patience=5)
early_stop_callback = tf.keras.callbacks.EarlyStopping(patience=25)

model_instance = constructModel()
model_instance.compile(loss='binary_crossentropy', optimizer=opt, metrics=['binary_crossentropy', 'mse'])
model_instance.fit(x=tr_dataset, validation_data=val_dataset, verbose=1, validation_steps=64,
                   steps_per_epoch=256, epochs=200,
                   callbacks=[save_best_callback, csv_logger_callback, lr_reduce_callback, early_stop_callback])
