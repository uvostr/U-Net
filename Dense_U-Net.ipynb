# %%
import speedup
import tensorflow as tf
import numpy as np
import tensorflow as tf
import random
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)

# %%
def conv_block(x, n_filters):
   x = tf.keras.layers.Conv2D(n_filters, (3, 3), activation = "relu", kernel_initializer = "he_normal", padding="same")(x)
   x = tf.keras.layers.BatchNormalization()(x)
   return x

# %%
def dense_block(x, n_filters, n_layers):
  for i in range(n_layers):
    cb = conv_block(x, n_filters)
    x = tf.keras.layers.concatenate([x, cb], axis=-1)
  return x

# %%
def downsample_block(x, n_filters):
   f = dense_block(x, n_filters, 4)
   p = tf.keras.layers.MaxPool2D((2, 2))(f)
   return f, p

# %%
def upsample_block(x, conv_features, n_filters):
   x = tf.keras.layers.Conv2DTranspose(n_filters, (3, 3), (2, 2), padding="same")(x)
   x = tf.keras.layers.BatchNormalization()(x)
   x = tf.keras.layers.concatenate([x, conv_features])
   x = tf.keras.layers.Conv2D(n_filters, (1, 1), activation = "relu", kernel_initializer = "he_normal", padding="same")(x)
   x = tf.keras.layers.BatchNormalization()(x)
   x = dense_block(x, n_filters, 4)
   return x

# %%
imageSize = 512
m = 3
min_w = 0.1
max_w = 0.5

def constructModel():
    inputs = tf.keras.Input(shape=(imageSize, imageSize, m))

    conv1 = conv_block(inputs, 32)

    f1, p1 = downsample_block(conv1, 64)
    f2, p2 = downsample_block(p1, 128)
    f3, p3 = downsample_block(p2, 256)
    f4, p4 = downsample_block(p3, 512)
  
    bottleneck = dense_block(p4, 1024, 4)

    u6 = upsample_block(bottleneck, f4, 512)
    u7 = upsample_block(u6, f3, 256)
    u8 = upsample_block(u7, f2, 128)
    u9 = upsample_block(u8, f1, 64)


    outputs = tf.keras.layers.Conv2D(3, (1, 1), activation='sigmoid', padding = "same")(u9)

    return tf.keras.Model(inputs, outputs, name="U-Net")

# %%
model_instance = constructModel()
model_instance.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  18496       ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  concatenate (Concatenate)      (None, 512, 512, 96  0           ['batch_normalization[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 64  55360       ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 512, 512, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  concatenate_1 (Concatenate)    (None, 512, 512, 16  0           ['concatenate[0][0]',
#                                 0)                                'batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 512, 512, 64  92224       ['concatenate_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 512, 512, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  concatenate_2 (Concatenate)    (None, 512, 512, 22  0           ['concatenate_1[0][0]',
#                                 4)                                'batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 512, 512, 64  129088      ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 512, 512, 64  256        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 28  0           ['concatenate_2[0][0]',
#                                 8)                                'batch_normalization_4[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 28  0           ['concatenate_3[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  331904      ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 256, 256, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 41  0           ['max_pooling2d[0][0]',
#                                 6)                                'batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 12  479360      ['concatenate_4[0][0]']
#                                 8)
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 12  512        ['conv2d_6[0][0]']
#  rmalization)                   8)
#
#  concatenate_5 (Concatenate)    (None, 256, 256, 54  0           ['concatenate_4[0][0]',
#                                 4)                                'batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 12  626816      ['concatenate_5[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 12  512        ['conv2d_7[0][0]']
#  rmalization)                   8)
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 67  0           ['concatenate_5[0][0]',
#                                 2)                                'batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 12  774272      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 12  512        ['conv2d_8[0][0]']
#  rmalization)                   8)
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 80  0           ['concatenate_6[0][0]',
#                                 0)                                'batch_normalization_8[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 80  0          ['concatenate_7[0][0]']
#                                 0)
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 25  1843456     ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_9[0][0]']
#  rmalization)                   6)
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 10  0           ['max_pooling2d_1[0][0]',
#                                 56)                               'batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 25  2433280     ['concatenate_8[0][0]']
#                                 6)
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 25  1024       ['conv2d_10[0][0]']
#  ormalization)                  6)
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 13  0           ['concatenate_8[0][0]',
#                                 12)                               'batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 25  3023104     ['concatenate_9[0][0]']
#                                 6)
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 25  1024       ['conv2d_11[0][0]']
#  ormalization)                  6)
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 15  0           ['concatenate_9[0][0]',
#                                 68)                               'batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  3612928     ['concatenate_10[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 18  0           ['concatenate_10[0][0]',
#                                 24)                               'batch_normalization_12[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 1824  0          ['concatenate_11[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 512)  8405504     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  concatenate_12 (Concatenate)   (None, 64, 64, 2336  0           ['max_pooling2d_2[0][0]',
#                                 )                                 'batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 512)  10764800    ['concatenate_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 2848  0           ['concatenate_12[0][0]',
#                                 )                                 'batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 512)  13124096    ['concatenate_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  concatenate_14 (Concatenate)   (None, 64, 64, 3360  0           ['concatenate_13[0][0]',
#                                 )                                 'batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 512)  15483392    ['concatenate_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_16[0][0]']
#  ormalization)
#
#  concatenate_15 (Concatenate)   (None, 64, 64, 3872  0           ['concatenate_14[0][0]',
#                                 )                                 'batch_normalization_16[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 3872  0          ['concatenate_15[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 1024  35685376    ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  concatenate_16 (Concatenate)   (None, 32, 32, 4896  0           ['max_pooling2d_3[0][0]',
#                                 )                                 'batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 1024  45122560    ['concatenate_16[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  concatenate_17 (Concatenate)   (None, 32, 32, 5920  0           ['concatenate_16[0][0]',
#                                 )                                 'batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 1024  54559744    ['concatenate_17[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  concatenate_18 (Concatenate)   (None, 32, 32, 6944  0           ['concatenate_17[0][0]',
#                                 )                                 'batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 1024  63996928    ['concatenate_18[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  concatenate_19 (Concatenate)   (None, 32, 32, 7968  0           ['concatenate_18[0][0]',
#                                 )                                 'batch_normalization_20[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  36717056   ['concatenate_19[0][0]']
#  ose)
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_transpose[0][0]']
#  ormalization)
#
#  concatenate_20 (Concatenate)   (None, 64, 64, 4384  0           ['batch_normalization_21[0][0]',
#                                 )                                 'concatenate_15[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 512)  2245120     ['concatenate_20[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_21[0][0]']
#  ormalization)
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 512)  2359808     ['batch_normalization_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_22[0][0]']
#  ormalization)
#
#  concatenate_21 (Concatenate)   (None, 64, 64, 1024  0           ['batch_normalization_22[0][0]',
#                                 )                                 'batch_normalization_23[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_23[0][0]']
#  ormalization)
#
#  concatenate_22 (Concatenate)   (None, 64, 64, 1536  0           ['concatenate_21[0][0]',
#                                 )                                 'batch_normalization_24[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 512)  7078400     ['concatenate_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_24[0][0]']
#  ormalization)
#
#  concatenate_23 (Concatenate)   (None, 64, 64, 2048  0           ['concatenate_22[0][0]',
#                                 )                                 'batch_normalization_25[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 512)  9437696     ['concatenate_23[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_25[0][0]']
#  ormalization)
#
#  concatenate_24 (Concatenate)   (None, 64, 64, 2560  0           ['concatenate_23[0][0]',
#                                 )                                 'batch_normalization_26[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  5898496    ['concatenate_24[0][0]']
#  spose)                         6)
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 25  1024       ['conv2d_transpose_1[0][0]']
#  ormalization)                  6)
#
#  concatenate_25 (Concatenate)   (None, 128, 128, 20  0           ['batch_normalization_27[0][0]',
#                                 80)                               'concatenate_11[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 25  532736      ['concatenate_25[0][0]']
#                                 6)
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 25  1024       ['conv2d_26[0][0]']
#  ormalization)                  6)
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 25  590080      ['batch_normalization_28[0][0]']
#                                 6)
#
#  batch_normalization_29 (BatchN  (None, 128, 128, 25  1024       ['conv2d_27[0][0]']
#  ormalization)                  6)
#
#  concatenate_26 (Concatenate)   (None, 128, 128, 51  0           ['batch_normalization_28[0][0]',
#                                 2)                                'batch_normalization_29[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_26[0][0]']
#                                 6)
#
#  batch_normalization_30 (BatchN  (None, 128, 128, 25  1024       ['conv2d_28[0][0]']
#  ormalization)                  6)
#
#  concatenate_27 (Concatenate)   (None, 128, 128, 76  0           ['concatenate_26[0][0]',
#                                 8)                                'batch_normalization_30[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 25  1769728     ['concatenate_27[0][0]']
#                                 6)
#
#  batch_normalization_31 (BatchN  (None, 128, 128, 25  1024       ['conv2d_29[0][0]']
#  ormalization)                  6)
#
#  concatenate_28 (Concatenate)   (None, 128, 128, 10  0           ['concatenate_27[0][0]',
#                                 24)                               'batch_normalization_31[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 25  2359552     ['concatenate_28[0][0]']
#                                 6)
#
#  batch_normalization_32 (BatchN  (None, 128, 128, 25  1024       ['conv2d_30[0][0]']
#  ormalization)                  6)
#
#  concatenate_29 (Concatenate)   (None, 128, 128, 12  0           ['concatenate_28[0][0]',
#                                 80)                               'batch_normalization_32[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  1474688    ['concatenate_29[0][0]']
#  spose)                         8)
#
#  batch_normalization_33 (BatchN  (None, 256, 256, 12  512        ['conv2d_transpose_2[0][0]']
#  ormalization)                  8)
#
#  concatenate_30 (Concatenate)   (None, 256, 256, 92  0           ['batch_normalization_33[0][0]',
#                                 8)                                'concatenate_7[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 256, 256, 12  118912      ['concatenate_30[0][0]']
#                                 8)
#
#  batch_normalization_34 (BatchN  (None, 256, 256, 12  512        ['conv2d_31[0][0]']
#  ormalization)                  8)
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 12  147584      ['batch_normalization_34[0][0]']
#                                 8)
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 12  512        ['conv2d_32[0][0]']
#  ormalization)                  8)
#
#  concatenate_31 (Concatenate)   (None, 256, 256, 25  0           ['batch_normalization_34[0][0]',
#                                 6)                                'batch_normalization_35[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_31[0][0]']
#                                 8)
#
#  batch_normalization_36 (BatchN  (None, 256, 256, 12  512        ['conv2d_33[0][0]']
#  ormalization)                  8)
#
#  concatenate_32 (Concatenate)   (None, 256, 256, 38  0           ['concatenate_31[0][0]',
#                                 4)                                'batch_normalization_36[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 12  442496      ['concatenate_32[0][0]']
#                                 8)
#
#  batch_normalization_37 (BatchN  (None, 256, 256, 12  512        ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  concatenate_33 (Concatenate)   (None, 256, 256, 51  0           ['concatenate_32[0][0]',
#                                 2)                                'batch_normalization_37[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 12  589952      ['concatenate_33[0][0]']
#                                 8)
#
#  batch_normalization_38 (BatchN  (None, 256, 256, 12  512        ['conv2d_35[0][0]']
#  ormalization)                  8)
#
#  concatenate_34 (Concatenate)   (None, 256, 256, 64  0           ['concatenate_33[0][0]',
#                                 0)                                'batch_normalization_38[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  368704     ['concatenate_34[0][0]']
#  spose)                         )
#
#  batch_normalization_39 (BatchN  (None, 512, 512, 64  256        ['conv2d_transpose_3[0][0]']
#  ormalization)                  )
#
#  concatenate_35 (Concatenate)   (None, 512, 512, 35  0           ['batch_normalization_39[0][0]',
#                                 2)                                'concatenate_3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 512, 512, 64  22592       ['concatenate_35[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 512, 512, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  conv2d_37 (Conv2D)             (None, 512, 512, 64  36928       ['batch_normalization_40[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 512, 512, 64  256        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  concatenate_36 (Concatenate)   (None, 512, 512, 12  0           ['batch_normalization_40[0][0]',
#                                 8)                                'batch_normalization_41[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_36[0][0]']
#                                 )
#
#  batch_normalization_42 (BatchN  (None, 512, 512, 64  256        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  concatenate_37 (Concatenate)   (None, 512, 512, 19  0           ['concatenate_36[0][0]',
#                                 2)                                'batch_normalization_42[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 512, 512, 64  110656      ['concatenate_37[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 512, 512, 64  256        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  concatenate_38 (Concatenate)   (None, 512, 512, 25  0           ['concatenate_37[0][0]',
#                                 6)                                'batch_normalization_43[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 512, 512, 64  147520      ['concatenate_38[0][0]']
#                                 )
#
#  batch_normalization_44 (BatchN  (None, 512, 512, 64  256        ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  concatenate_39 (Concatenate)   (None, 512, 512, 32  0           ['concatenate_38[0][0]',
#                                 0)                                'batch_normalization_44[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 512, 512, 3)  963         ['concatenate_39[0][0]']
#
# ==================================================================================================
# Total params: 339,336,003
# Trainable params: 339,308,547
# Non-trainable params: 27,456
# __________________________________________________________________________________________________

# %%
image_path = '/content/drive/MyDrive/source2'
models_path = '/content/drive/MyDrive/models/'

# %%
import itertools
import tensorflow as tf
from speedup import generate_out_images
import numpy as np
from random import randint, uniform
import imageio
import time


source_num = 2999
dim = 512
stationary_defocus = 0.05


def gen():
    while True:
        layer1_number = randint(0, source_num)
        layer2_number = randint(0, source_num)
        layer3_number = randint(0, source_num)

        src1 = imageio.imread(image_path + '/image' + str(layer1_number).zfill(4) + '.png')
        src2 = imageio.imread(image_path + '/image' + str(layer2_number).zfill(4) + '.png')
        src3 = imageio.imread(image_path + '/image' + str(layer3_number).zfill(4) + '.png')
        src = np.zeros((dim, dim, m), np.double)
        src[:, :, 0] = src1[:, :, 0]
        src[:, :, 1] = src2[:, :, 0]
        src[:, :, 2] = src3[:, :, 0]
        src = src - np.amin(src)
        src = src / np.amax(src)

        w_rand = uniform(min_w, max_w)

        out = generate_out_images(dim, m, w_rand, stationary_defocus, src)[1]

        out = out / np.amax(out)

        src[src > 0] = 1.

        yield (out, src)


tr_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .batch(batch_size=1).prefetch(buffer_size=8)

val_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .take(count=128).cache().batch(batch_size=1)


opt = tf.keras.optimizers.Adam(learning_rate=1e-5)

save_best_callback = tf.keras.callbacks.ModelCheckpoint(models_path + 'bestmodel_dense_unet.hdf5',
                                                        save_weights_only=True,save_best_only=True, verbose=True)
csv_logger_callback = tf.keras.callbacks.CSVLogger(models_path + 'log_dense_unet.csv')
lr_reduce_callback = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, min_delta=5e-4, patience=5)
early_stop_callback = tf.keras.callbacks.EarlyStopping(patience=25)

model_instance = constructModel()
model_instance.compile(loss="binary_crossentropy", optimizer=opt, metrics=['binary_crossentropy', "mse"])
model_instance.fit(x=tr_dataset, validation_data=val_dataset, verbose=1, validation_steps=128,
                   steps_per_epoch=512, epochs=200,
                   callbacks=[save_best_callback, csv_logger_callback, lr_reduce_callback, early_stop_callback])
