# %%
import speedup
import tensorflow as tf
import numpy as np
import tensorflow as tf
import random
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)

# %%
def dense_block(x, n_filters, n_layers):
  for i in range(n_layers):
    cb = tf.keras.layers.Conv2D(n_filters * 4, (1, 1), activation = "relu", kernel_initializer = "he_normal", padding="same")(x)
    cb = tf.keras.layers.BatchNormalization()(cb)
    cb = tf.keras.layers.Conv2D(n_filters, (3, 3), activation = "relu", kernel_initializer = "he_normal", padding="same")(cb)
    cb = tf.keras.layers.BatchNormalization()(cb)
    x = tf.keras.layers.concatenate([x, cb], axis=-1)
  return x

# %%
def downsample_block(x, n_filters):
   f = dense_block(x, n_filters, 4)
   p = tf.keras.layers.MaxPool2D((2, 2))(f)
   return f, p

# %%
def upsample_block(x, conv_features, n_filters):
   x = tf.keras.layers.Conv2DTranspose(n_filters * 8, (3, 3), (2, 2), padding="same")(x)
   x = tf.keras.layers.BatchNormalization()(x)
   x = tf.keras.layers.concatenate([x, conv_features])
   x = tf.keras.layers.Conv2D(n_filters * 4, (1, 1), activation = "relu", kernel_initializer = "he_normal", padding="same")(x)
   x = tf.keras.layers.BatchNormalization()(x)
   x = dense_block(x, n_filters, 4)
   return x

# %%
imageSize = 512
m = 3

def constructModel():
    inputs = tf.keras.Input(shape=(imageSize, imageSize, m))

    conv1 = tf.keras.layers.Conv2D(32, (3, 3), activation = "relu", kernel_initializer = "he_normal", padding="same")(inputs)
    conv1 = tf.keras.layers.BatchNormalization()(conv1)

    f1, p1 = downsample_block(conv1, 8)
    f2, p2 = downsample_block(p1, 16)
    f3, p3 = downsample_block(p2, 32)
    f4, p4 = downsample_block(p3, 64)
  
    bottleneck = dense_block(p4, 128, 4)

    u6 = upsample_block(bottleneck, f4, 64)
    u7 = upsample_block(u6, f3, 32)
    u8 = upsample_block(u7, f2, 16)
    u9 = upsample_block(u8, f1, 8)


    outputs = tf.keras.layers.Conv2D(3, (1, 1), activation='sigmoid', padding = "same")(u9)

    return tf.keras.Model(inputs, outputs, name="U-Net")

# %%
model_instance = constructModel()
model_instance.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 32  1056        ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 8)  2312        ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 512, 512, 8)  32         ['conv2d_2[0][0]']
#  rmalization)
#
#  concatenate (Concatenate)      (None, 512, 512, 40  0           ['batch_normalization[0][0]',
#                                 )                                 'batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 512, 512, 32  1312        ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 512, 512, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  conv2d_4 (Conv2D)              (None, 512, 512, 8)  2312        ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 512, 512, 8)  32         ['conv2d_4[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 512, 512, 48  0           ['concatenate[0][0]',
#                                 )                                 'batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 512, 512, 32  1568        ['concatenate_1[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 512, 512, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 8)  2312        ['batch_normalization_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 512, 512, 8)  32         ['conv2d_6[0][0]']
#  rmalization)
#
#  concatenate_2 (Concatenate)    (None, 512, 512, 56  0           ['concatenate_1[0][0]',
#                                 )                                 'batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 32  1824        ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 512, 512, 32  128        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 8)  2312        ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 512, 512, 8)  32         ['conv2d_8[0][0]']
#  rmalization)
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 64  0           ['concatenate_2[0][0]',
#                                 )                                 'batch_normalization_8[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 256, 256, 64  4160        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 256, 256, 64  256        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 16  9232        ['batch_normalization_9[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 256, 256, 16  64         ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 80  0           ['max_pooling2d[0][0]',
#                                 )                                 'batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 256, 256, 64  5184        ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 256, 256, 64  256        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  conv2d_12 (Conv2D)             (None, 256, 256, 16  9232        ['batch_normalization_11[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 16  64         ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  concatenate_5 (Concatenate)    (None, 256, 256, 96  0           ['concatenate_4[0][0]',
#                                 )                                 'batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 64  6208        ['concatenate_5[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 16  9232        ['batch_normalization_13[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 16  64         ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 11  0           ['concatenate_5[0][0]',
#                                 2)                                'batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 64  7232        ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 64  256        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 16  9232        ['batch_normalization_15[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 16  64         ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 12  0           ['concatenate_6[0][0]',
#                                 8)                                'batch_normalization_16[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['concatenate_7[0][0]']
#                                 8)
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 12  16512       ['max_pooling2d_1[0][0]']
#                                 8)
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 12  512        ['conv2d_17[0][0]']
#  ormalization)                  8)
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 32  36896       ['batch_normalization_17[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 32  128        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 16  0           ['max_pooling2d_1[0][0]',
#                                 0)                                'batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 12  20608       ['concatenate_8[0][0]']
#                                 8)
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 12  512        ['conv2d_19[0][0]']
#  ormalization)                  8)
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 32  36896       ['batch_normalization_19[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 32  128        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 19  0           ['concatenate_8[0][0]',
#                                 2)                                'batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 12  24704       ['concatenate_9[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 12  512        ['conv2d_21[0][0]']
#  ormalization)                  8)
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 32  36896       ['batch_normalization_21[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 32  128        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 22  0           ['concatenate_9[0][0]',
#                                 4)                                'batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 12  28800       ['concatenate_10[0][0]']
#                                 8)
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 12  512        ['conv2d_23[0][0]']
#  ormalization)                  8)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 32  36896       ['batch_normalization_23[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 32  128        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 25  0           ['concatenate_10[0][0]',
#                                 6)                                'batch_normalization_24[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['concatenate_11[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 256)  65792       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 64)   147520      ['batch_normalization_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  concatenate_12 (Concatenate)   (None, 64, 64, 320)  0           ['max_pooling2d_2[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 256)  82176       ['concatenate_12[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 64)   147520      ['batch_normalization_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 384)  0           ['concatenate_12[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 256)  98560       ['concatenate_13[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 64)   147520      ['batch_normalization_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  concatenate_14 (Concatenate)   (None, 64, 64, 448)  0           ['concatenate_13[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 256)  114944      ['concatenate_14[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 64)   147520      ['batch_normalization_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  concatenate_15 (Concatenate)   (None, 64, 64, 512)  0           ['concatenate_14[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['concatenate_15[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 512)  262656      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_33[0][0]']
#  ormalization)
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 128)  589952      ['batch_normalization_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  concatenate_16 (Concatenate)   (None, 32, 32, 640)  0           ['max_pooling2d_3[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 512)  328192      ['concatenate_16[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_35[0][0]']
#  ormalization)
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 128)  589952      ['batch_normalization_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 128)  512        ['conv2d_36[0][0]']
#  ormalization)
#
#  concatenate_17 (Concatenate)   (None, 32, 32, 768)  0           ['concatenate_16[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 512)  393728      ['concatenate_17[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_37[0][0]']
#  ormalization)
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 128)  589952      ['batch_normalization_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 128)  512        ['conv2d_38[0][0]']
#  ormalization)
#
#  concatenate_18 (Concatenate)   (None, 32, 32, 896)  0           ['concatenate_17[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 512)  459264      ['concatenate_18[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_39[0][0]']
#  ormalization)
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 128)  589952      ['batch_normalization_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 128)  512        ['conv2d_40[0][0]']
#  ormalization)
#
#  concatenate_19 (Concatenate)   (None, 32, 32, 1024  0           ['concatenate_18[0][0]',
#                                 )                                 'batch_normalization_40[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  4719104    ['concatenate_19[0][0]']
#  ose)
#
#  batch_normalization_41 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_transpose[0][0]']
#  ormalization)
#
#  concatenate_20 (Concatenate)   (None, 64, 64, 1024  0           ['batch_normalization_41[0][0]',
#                                 )                                 'concatenate_15[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 256)  262400      ['concatenate_20[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_41[0][0]']
#  ormalization)
#
#  conv2d_42 (Conv2D)             (None, 64, 64, 256)  65792       ['batch_normalization_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_42[0][0]']
#  ormalization)
#
#  conv2d_43 (Conv2D)             (None, 64, 64, 64)   147520      ['batch_normalization_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 64, 64, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  concatenate_21 (Concatenate)   (None, 64, 64, 320)  0           ['batch_normalization_42[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 64, 64, 256)  82176       ['concatenate_21[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_44[0][0]']
#  ormalization)
#
#  conv2d_45 (Conv2D)             (None, 64, 64, 64)   147520      ['batch_normalization_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 64, 64, 64)  256         ['conv2d_45[0][0]']
#  ormalization)
#
#  concatenate_22 (Concatenate)   (None, 64, 64, 384)  0           ['concatenate_21[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 64, 64, 256)  98560       ['concatenate_22[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_46[0][0]']
#  ormalization)
#
#  conv2d_47 (Conv2D)             (None, 64, 64, 64)   147520      ['batch_normalization_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 64, 64, 64)  256         ['conv2d_47[0][0]']
#  ormalization)
#
#  concatenate_23 (Concatenate)   (None, 64, 64, 448)  0           ['concatenate_22[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 64, 64, 256)  114944      ['concatenate_23[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_48[0][0]']
#  ormalization)
#
#  conv2d_49 (Conv2D)             (None, 64, 64, 64)   147520      ['batch_normalization_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 64)  256         ['conv2d_49[0][0]']
#  ormalization)
#
#  concatenate_24 (Concatenate)   (None, 64, 64, 512)  0           ['concatenate_23[0][0]',
#                                                                   'batch_normalization_50[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  1179904    ['concatenate_24[0][0]']
#  spose)                         6)
#
#  batch_normalization_51 (BatchN  (None, 128, 128, 25  1024       ['conv2d_transpose_1[0][0]']
#  ormalization)                  6)
#
#  concatenate_25 (Concatenate)   (None, 128, 128, 51  0           ['batch_normalization_51[0][0]',
#                                 2)                                'concatenate_11[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 128, 128, 12  65664       ['concatenate_25[0][0]']
#                                 8)
#
#  batch_normalization_52 (BatchN  (None, 128, 128, 12  512        ['conv2d_50[0][0]']
#  ormalization)                  8)
#
#  conv2d_51 (Conv2D)             (None, 128, 128, 12  16512       ['batch_normalization_52[0][0]']
#                                 8)
#
#  batch_normalization_53 (BatchN  (None, 128, 128, 12  512        ['conv2d_51[0][0]']
#  ormalization)                  8)
#
#  conv2d_52 (Conv2D)             (None, 128, 128, 32  36896       ['batch_normalization_53[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 128, 128, 32  128        ['conv2d_52[0][0]']
#  ormalization)                  )
#
#  concatenate_26 (Concatenate)   (None, 128, 128, 16  0           ['batch_normalization_52[0][0]',
#                                 0)                                'batch_normalization_54[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 128, 128, 12  20608       ['concatenate_26[0][0]']
#                                 8)
#
#  batch_normalization_55 (BatchN  (None, 128, 128, 12  512        ['conv2d_53[0][0]']
#  ormalization)                  8)
#
#  conv2d_54 (Conv2D)             (None, 128, 128, 32  36896       ['batch_normalization_55[0][0]']
#                                 )
#
#  batch_normalization_56 (BatchN  (None, 128, 128, 32  128        ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  concatenate_27 (Concatenate)   (None, 128, 128, 19  0           ['concatenate_26[0][0]',
#                                 2)                                'batch_normalization_56[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 128, 128, 12  24704       ['concatenate_27[0][0]']
#                                 8)
#
#  batch_normalization_57 (BatchN  (None, 128, 128, 12  512        ['conv2d_55[0][0]']
#  ormalization)                  8)
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 32  36896       ['batch_normalization_57[0][0]']
#                                 )
#
#  batch_normalization_58 (BatchN  (None, 128, 128, 32  128        ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  concatenate_28 (Concatenate)   (None, 128, 128, 22  0           ['concatenate_27[0][0]',
#                                 4)                                'batch_normalization_58[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 12  28800       ['concatenate_28[0][0]']
#                                 8)
#
#  batch_normalization_59 (BatchN  (None, 128, 128, 12  512        ['conv2d_57[0][0]']
#  ormalization)                  8)
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 32  36896       ['batch_normalization_59[0][0]']
#                                 )
#
#  batch_normalization_60 (BatchN  (None, 128, 128, 32  128        ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  concatenate_29 (Concatenate)   (None, 128, 128, 25  0           ['concatenate_28[0][0]',
#                                 6)                                'batch_normalization_60[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  295040     ['concatenate_29[0][0]']
#  spose)                         8)
#
#  batch_normalization_61 (BatchN  (None, 256, 256, 12  512        ['conv2d_transpose_2[0][0]']
#  ormalization)                  8)
#
#  concatenate_30 (Concatenate)   (None, 256, 256, 25  0           ['batch_normalization_61[0][0]',
#                                 6)                                'concatenate_7[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 256, 256, 64  16448       ['concatenate_30[0][0]']
#                                 )
#
#  batch_normalization_62 (BatchN  (None, 256, 256, 64  256        ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  conv2d_60 (Conv2D)             (None, 256, 256, 64  4160        ['batch_normalization_62[0][0]']
#                                 )
#
#  batch_normalization_63 (BatchN  (None, 256, 256, 64  256        ['conv2d_60[0][0]']
#  ormalization)                  )
#
#  conv2d_61 (Conv2D)             (None, 256, 256, 16  9232        ['batch_normalization_63[0][0]']
#                                 )
#
#  batch_normalization_64 (BatchN  (None, 256, 256, 16  64         ['conv2d_61[0][0]']
#  ormalization)                  )
#
#  concatenate_31 (Concatenate)   (None, 256, 256, 80  0           ['batch_normalization_62[0][0]',
#                                 )                                 'batch_normalization_64[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 256, 256, 64  5184        ['concatenate_31[0][0]']
#                                 )
#
#  batch_normalization_65 (BatchN  (None, 256, 256, 64  256        ['conv2d_62[0][0]']
#  ormalization)                  )
#
#  conv2d_63 (Conv2D)             (None, 256, 256, 16  9232        ['batch_normalization_65[0][0]']
#                                 )
#
#  batch_normalization_66 (BatchN  (None, 256, 256, 16  64         ['conv2d_63[0][0]']
#  ormalization)                  )
#
#  concatenate_32 (Concatenate)   (None, 256, 256, 96  0           ['concatenate_31[0][0]',
#                                 )                                 'batch_normalization_66[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 256, 256, 64  6208        ['concatenate_32[0][0]']
#                                 )
#
#  batch_normalization_67 (BatchN  (None, 256, 256, 64  256        ['conv2d_64[0][0]']
#  ormalization)                  )
#
#  conv2d_65 (Conv2D)             (None, 256, 256, 16  9232        ['batch_normalization_67[0][0]']
#                                 )
#
#  batch_normalization_68 (BatchN  (None, 256, 256, 16  64         ['conv2d_65[0][0]']
#  ormalization)                  )
#
#  concatenate_33 (Concatenate)   (None, 256, 256, 11  0           ['concatenate_32[0][0]',
#                                 2)                                'batch_normalization_68[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 256, 256, 64  7232        ['concatenate_33[0][0]']
#                                 )
#
#  batch_normalization_69 (BatchN  (None, 256, 256, 64  256        ['conv2d_66[0][0]']
#  ormalization)                  )
#
#  conv2d_67 (Conv2D)             (None, 256, 256, 16  9232        ['batch_normalization_69[0][0]']
#                                 )
#
#  batch_normalization_70 (BatchN  (None, 256, 256, 16  64         ['conv2d_67[0][0]']
#  ormalization)                  )
#
#  concatenate_34 (Concatenate)   (None, 256, 256, 12  0           ['concatenate_33[0][0]',
#                                 8)                                'batch_normalization_70[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  73792      ['concatenate_34[0][0]']
#  spose)                         )
#
#  batch_normalization_71 (BatchN  (None, 512, 512, 64  256        ['conv2d_transpose_3[0][0]']
#  ormalization)                  )
#
#  concatenate_35 (Concatenate)   (None, 512, 512, 12  0           ['batch_normalization_71[0][0]',
#                                 8)                                'concatenate_3[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 512, 512, 32  4128        ['concatenate_35[0][0]']
#                                 )
#
#  batch_normalization_72 (BatchN  (None, 512, 512, 32  128        ['conv2d_68[0][0]']
#  ormalization)                  )
#
#  conv2d_69 (Conv2D)             (None, 512, 512, 32  1056        ['batch_normalization_72[0][0]']
#                                 )
#
#  batch_normalization_73 (BatchN  (None, 512, 512, 32  128        ['conv2d_69[0][0]']
#  ormalization)                  )
#
#  conv2d_70 (Conv2D)             (None, 512, 512, 8)  2312        ['batch_normalization_73[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 512, 512, 8)  32         ['conv2d_70[0][0]']
#  ormalization)
#
#  concatenate_36 (Concatenate)   (None, 512, 512, 40  0           ['batch_normalization_72[0][0]',
#                                 )                                 'batch_normalization_74[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 512, 512, 32  1312        ['concatenate_36[0][0]']
#                                 )
#
#  batch_normalization_75 (BatchN  (None, 512, 512, 32  128        ['conv2d_71[0][0]']
#  ormalization)                  )
#
#  conv2d_72 (Conv2D)             (None, 512, 512, 8)  2312        ['batch_normalization_75[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 512, 512, 8)  32         ['conv2d_72[0][0]']
#  ormalization)
#
#  concatenate_37 (Concatenate)   (None, 512, 512, 48  0           ['concatenate_36[0][0]',
#                                 )                                 'batch_normalization_76[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 512, 512, 32  1568        ['concatenate_37[0][0]']
#                                 )
#
#  batch_normalization_77 (BatchN  (None, 512, 512, 32  128        ['conv2d_73[0][0]']
#  ormalization)                  )
#
#  conv2d_74 (Conv2D)             (None, 512, 512, 8)  2312        ['batch_normalization_77[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 512, 512, 8)  32         ['conv2d_74[0][0]']
#  ormalization)
#
#  concatenate_38 (Concatenate)   (None, 512, 512, 56  0           ['concatenate_37[0][0]',
#                                 )                                 'batch_normalization_78[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 512, 512, 32  1824        ['concatenate_38[0][0]']
#                                 )
#
#  batch_normalization_79 (BatchN  (None, 512, 512, 32  128        ['conv2d_75[0][0]']
#  ormalization)                  )
#
#  conv2d_76 (Conv2D)             (None, 512, 512, 8)  2312        ['batch_normalization_79[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 512, 512, 8)  32         ['conv2d_76[0][0]']
#  ormalization)
#
#  concatenate_39 (Concatenate)   (None, 512, 512, 64  0           ['concatenate_38[0][0]',
#                                 )                                 'batch_normalization_80[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 512, 512, 3)  195         ['concatenate_39[0][0]']
#
# ==================================================================================================
# Total params: 12,985,507
# Trainable params: 12,967,843
# Non-trainable params: 17,664
# __________________________________________________________________________________________________

# %%
image_path = '/content/drive/MyDrive/source2'
models_path = '/content/drive/MyDrive/models/'

# %%
import itertools
import tensorflow as tf
from speedup import generate_out_images3
import numpy as np
from random import randint, uniform
import imageio
import time


source_num = 2999
dim = 512
stationary_defocus = 0.05


def gen():
    while True:
        layer1_number = randint(0, source_num)
        layer2_number = randint(0, source_num)
        layer3_number = randint(0, source_num)

        src1 = imageio.imread(image_path + '/image' + str(layer1_number).zfill(4) + '.png')
        src2 = imageio.imread(image_path + '/image' + str(layer2_number).zfill(4) + '.png')
        src3 = imageio.imread(image_path + '/image' + str(layer3_number).zfill(4) + '.png')
        src = np.zeros((dim, dim, m), np.double)
        src[:, :, 0] = src1[:, :, 0]
        src[:, :, 1] = src2[:, :, 0]
        src[:, :, 2] = src3[:, :, 0]
        src = src - np.amin(src)
        src = src / np.amax(src)

        w = uniform(0.05, 0.5) 
        
        a_10 = uniform(-1e3, 1e3)
        a_01 = uniform(-1e3, 1e3)
        b_20 = uniform(1, 1.5)
        b_11 = uniform(-0.1, 0.1)
        b_02 = uniform(1, 1.5)
        c_30 = uniform(-1.5e-6, 1.5e-6)
        c_21 = uniform(-2e-6, 2e-6)
        c_12 = uniform(-2e-6, 2e-6)
        c_03 = uniform(-1.5e-6, 1.5e-6)

        out = generate_out_images3(dim, m, w, stationary_defocus, a_10, a_01, b_20, b_11, b_02, c_30, c_21, c_12, c_03, src)[1]

        out = out / np.amax(out)

        src[src > 0] = 1.

        yield (out, src)

tr_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .batch(batch_size=2).prefetch(buffer_size=8)

val_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .take(count=128).cache().batch(batch_size=2)


opt = tf.keras.optimizers.Adam(learning_rate=1e-3)

save_best_callback = tf.keras.callbacks.ModelCheckpoint(models_path + 'bestmodel_dense_unet.hdf5',
                                                        save_weights_only=True,save_best_only=True, verbose=True)
csv_logger_callback = tf.keras.callbacks.CSVLogger(models_path + 'log_dense_unet.csv')
lr_reduce_callback = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, min_delta=5e-4, patience=5)
early_stop_callback = tf.keras.callbacks.EarlyStopping(patience=25)

model_instance = constructModel()
model_instance.compile(loss="binary_crossentropy", optimizer=opt, metrics=['binary_crossentropy', "mse"])
model_instance.fit(x=tr_dataset, validation_data=val_dataset, verbose=1, validation_steps=64,
                   steps_per_epoch=256, epochs=200,
                   callbacks=[save_best_callback, csv_logger_callback, lr_reduce_callback, early_stop_callback])
