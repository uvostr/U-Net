# %%
import speedup
import tensorflow as tf
import numpy as np
import random
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)

# %%
def reshape_tensor(x, heads, flag):
    if flag:
        x = tf.reshape(x, shape=(tf.shape(x)[0], tf.shape(x)[1], heads, -1))
        x = tf.transpose(x, perm=(0, 2, 1, 3))
    else:
        x = tf.reshape(x, shape=(-1, heads, tf.shape(x)[1], tf.shape(x)[2]))
        x = tf.transpose(x, perm=(0, 2, 1, 3))
    return x

# %%
#Multi-DConv Head Transposed Self-Attention (MDTA)
def MDTA(x, n_filters, num_heads):
  b,c,h,w = x.shape

  x0 = tf.keras.layers.Normalization()(x)

  q = tf.keras.layers.Conv2D(n_filters, (1, 1), padding="same")(x0)
  k = tf.keras.layers.Conv2D(n_filters, (1, 1), padding="same")(x0)
  v = tf.keras.layers.Conv2D(n_filters, (1, 1), padding="same")(x0)

  q = tf.keras.layers.DepthwiseConv2D((3, 3), padding="same")(q)
  k = tf.keras.layers.DepthwiseConv2D((3, 3), padding="same")(k)
  v = tf.keras.layers.DepthwiseConv2D((3, 3), padding="same")(v)

  q = reshape_tensor(q, num_heads, True)
  k = reshape_tensor(k, num_heads, True)
  v = reshape_tensor(v, num_heads, True)

  #k = tf.transpose(k, [-2, -1])

  #attn = tf.matmul(q, k)
  #attn = tf.keras.activations.softmax(attn)

  #out = tf.matmul(attn, v)

  #out = reshape_tensor(v, num_heads, False)
  #out = tf.keras.layers.Conv2D(n_filters, (1, 1), padding="same")(out)

  #x = x + out
  return q

# %%
#Gate-Dconv Feed-Forward Network (GDFN)
def GDFN(x, n_filters):
  x0 = tf.keras.layers.Normalization()(x)

  x1 = tf.keras.layers.Conv2D(n_filters * 2, (1, 1), padding="same")(x0)
  x2 = tf.keras.layers.Conv2D(n_filters * 2, (1, 1), padding="same")(x0)

  x1 = tf.keras.layers.DepthwiseConv2D((3, 3), padding="same")(x1)
  x2 = tf.keras.layers.DepthwiseConv2D((3, 3), padding="same")(x2)
  x0 = tf.keras.activations.gelu(x1) * x2
  x0 = tf.keras.layers.Conv2D(n_filters, (1, 1), padding="same")(x0)

  x = x + x0
  return x0

# %%
def Transformer_block(x, n_filters, num_heads):
  x = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=2, attention_axes=(3))(x, x)
  #x = MDTA(x, n_filters, num_heads)
  x = GDFN(x, n_filters)
  return x

# %%
def seq_transformer_blocks(x, n_filters, num_heads, num_blocks):
  for i in range(num_blocks):
    x = Transformer_block(x, n_filters, num_heads)
  return x

# %%
def downsample_block(x, n_filters, num_heads, num_blocks):
   f = seq_transformer_blocks(x, n_filters, num_heads, num_blocks)
   p = tf.keras.layers.Conv2D(n_filters * 2, (1, 1), padding="same")(f)
   p = tf.keras.layers.MaxPool2D((2, 2))(p)
   return f, p

# %%
def upsample_block(x, conv_features, n_filters, num_heads, num_blocks):
   x = tf.keras.layers.Conv2DTranspose(n_filters, (3, 3), (2, 2), padding="same")(x)
   x = tf.keras.layers.concatenate([x, conv_features])
   x = tf.keras.layers.Conv2D(n_filters, (1, 1), padding="same")(x)
   x = seq_transformer_blocks(x, n_filters, num_heads, num_blocks)
   return x

# %%
imageSize = 512
m = 3

def constructModel():
    inputs = tf.keras.Input(shape=(imageSize, imageSize, m))
    x = tf.keras.layers.DepthwiseConv2D((3, 3), padding="same")(inputs)

    f1, p1 = downsample_block(x, m, 1, 4)
    f2, p2 = downsample_block(p1, m * 2, 2, 6)
    f3, p3 = downsample_block(p2, m * 4, 4, 6)

    bottleneck = seq_transformer_blocks(p3, m * 8, 8, 8)

    u6 = upsample_block(bottleneck, f3, m * 4, 4, 6)
    u7 = upsample_block(u6, f2, m * 2, 2, 6)
    u8 = upsample_block(u7, f1, m, 1, 4)
    refinement = seq_transformer_blocks(u8, m, 1, 4)
    outputs = tf.keras.layers.DepthwiseConv2D((3, 3), padding="same")(refinement)  

    outputs = inputs + outputs

    return tf.keras.Model(inputs, outputs, name="CNN_Transformer")

# %%
model_instance = constructModel()
model_instance.summary()
# Out:
# Model: "CNN_Transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  depthwise_conv2d_178 (Depthwis  (None, 512, 512, 3)  30         ['input_3[0][0]']
#  eConv2D)
#
#  multi_head_attention_88 (Multi  (None, 512, 512, 3)  33         ['depthwise_conv2d_178[0][0]',
#  HeadAttention)                                                   'depthwise_conv2d_178[0][0]']
#
#  normalization_88 (Normalizatio  (None, 512, 512, 3)  7          ['multi_head_attention_88[0][0]']
#  n)
#
#  conv2d_276 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_88[0][0]']
#
#  depthwise_conv2d_179 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_276[0][0]']
#  eConv2D)
#
#  conv2d_277 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_88[0][0]']
#
#  tf.nn.gelu_88 (TFOpLambda)     (None, 512, 512, 6)  0           ['depthwise_conv2d_179[0][0]']
#
#  depthwise_conv2d_180 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_277[0][0]']
#  eConv2D)
#
#  tf.math.multiply_88 (TFOpLambd  (None, 512, 512, 6)  0          ['tf.nn.gelu_88[0][0]',
#  a)                                                               'depthwise_conv2d_180[0][0]']
#
#  conv2d_278 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_88[0][0]']
#
#  multi_head_attention_89 (Multi  (None, 512, 512, 3)  33         ['conv2d_278[0][0]',
#  HeadAttention)                                                   'conv2d_278[0][0]']
#
#  normalization_89 (Normalizatio  (None, 512, 512, 3)  7          ['multi_head_attention_89[0][0]']
#  n)
#
#  conv2d_279 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_89[0][0]']
#
#  depthwise_conv2d_181 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_279[0][0]']
#  eConv2D)
#
#  conv2d_280 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_89[0][0]']
#
#  tf.nn.gelu_89 (TFOpLambda)     (None, 512, 512, 6)  0           ['depthwise_conv2d_181[0][0]']
#
#  depthwise_conv2d_182 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_280[0][0]']
#  eConv2D)
#
#  tf.math.multiply_89 (TFOpLambd  (None, 512, 512, 6)  0          ['tf.nn.gelu_89[0][0]',
#  a)                                                               'depthwise_conv2d_182[0][0]']
#
#  conv2d_281 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_89[0][0]']
#
#  multi_head_attention_90 (Multi  (None, 512, 512, 3)  33         ['conv2d_281[0][0]',
#  HeadAttention)                                                   'conv2d_281[0][0]']
#
#  normalization_90 (Normalizatio  (None, 512, 512, 3)  7          ['multi_head_attention_90[0][0]']
#  n)
#
#  conv2d_282 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_90[0][0]']
#
#  depthwise_conv2d_183 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_282[0][0]']
#  eConv2D)
#
#  conv2d_283 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_90[0][0]']
#
#  tf.nn.gelu_90 (TFOpLambda)     (None, 512, 512, 6)  0           ['depthwise_conv2d_183[0][0]']
#
#  depthwise_conv2d_184 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_283[0][0]']
#  eConv2D)
#
#  tf.math.multiply_90 (TFOpLambd  (None, 512, 512, 6)  0          ['tf.nn.gelu_90[0][0]',
#  a)                                                               'depthwise_conv2d_184[0][0]']
#
#  conv2d_284 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_90[0][0]']
#
#  multi_head_attention_91 (Multi  (None, 512, 512, 3)  33         ['conv2d_284[0][0]',
#  HeadAttention)                                                   'conv2d_284[0][0]']
#
#  normalization_91 (Normalizatio  (None, 512, 512, 3)  7          ['multi_head_attention_91[0][0]']
#  n)
#
#  conv2d_285 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_91[0][0]']
#
#  depthwise_conv2d_185 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_285[0][0]']
#  eConv2D)
#
#  conv2d_286 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_91[0][0]']
#
#  tf.nn.gelu_91 (TFOpLambda)     (None, 512, 512, 6)  0           ['depthwise_conv2d_185[0][0]']
#
#  depthwise_conv2d_186 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_286[0][0]']
#  eConv2D)
#
#  tf.math.multiply_91 (TFOpLambd  (None, 512, 512, 6)  0          ['tf.nn.gelu_91[0][0]',
#  a)                                                               'depthwise_conv2d_186[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_91[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 512, 512, 6)  24          ['conv2d_287[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 256, 256, 6)  0          ['conv2d_288[0][0]']
#
#  multi_head_attention_92 (Multi  (None, 256, 256, 6)  114        ['max_pooling2d_6[0][0]',
#  HeadAttention)                                                   'max_pooling2d_6[0][0]']
#
#  normalization_92 (Normalizatio  (None, 256, 256, 6)  13         ['multi_head_attention_92[0][0]']
#  n)
#
#  conv2d_289 (Conv2D)            (None, 256, 256, 12  84          ['normalization_92[0][0]']
#                                 )
#
#  depthwise_conv2d_187 (Depthwis  (None, 256, 256, 12  120        ['conv2d_289[0][0]']
#  eConv2D)                       )
#
#  conv2d_290 (Conv2D)            (None, 256, 256, 12  84          ['normalization_92[0][0]']
#                                 )
#
#  tf.nn.gelu_92 (TFOpLambda)     (None, 256, 256, 12  0           ['depthwise_conv2d_187[0][0]']
#                                 )
#
#  depthwise_conv2d_188 (Depthwis  (None, 256, 256, 12  120        ['conv2d_290[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_92 (TFOpLambd  (None, 256, 256, 12  0          ['tf.nn.gelu_92[0][0]',
#  a)                             )                                 'depthwise_conv2d_188[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 256, 256, 6)  78          ['tf.math.multiply_92[0][0]']
#
#  multi_head_attention_93 (Multi  (None, 256, 256, 6)  114        ['conv2d_291[0][0]',
#  HeadAttention)                                                   'conv2d_291[0][0]']
#
#  normalization_93 (Normalizatio  (None, 256, 256, 6)  13         ['multi_head_attention_93[0][0]']
#  n)
#
#  conv2d_292 (Conv2D)            (None, 256, 256, 12  84          ['normalization_93[0][0]']
#                                 )
#
#  depthwise_conv2d_189 (Depthwis  (None, 256, 256, 12  120        ['conv2d_292[0][0]']
#  eConv2D)                       )
#
#  conv2d_293 (Conv2D)            (None, 256, 256, 12  84          ['normalization_93[0][0]']
#                                 )
#
#  tf.nn.gelu_93 (TFOpLambda)     (None, 256, 256, 12  0           ['depthwise_conv2d_189[0][0]']
#                                 )
#
#  depthwise_conv2d_190 (Depthwis  (None, 256, 256, 12  120        ['conv2d_293[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_93 (TFOpLambd  (None, 256, 256, 12  0          ['tf.nn.gelu_93[0][0]',
#  a)                             )                                 'depthwise_conv2d_190[0][0]']
#
#  conv2d_294 (Conv2D)            (None, 256, 256, 6)  78          ['tf.math.multiply_93[0][0]']
#
#  multi_head_attention_94 (Multi  (None, 256, 256, 6)  114        ['conv2d_294[0][0]',
#  HeadAttention)                                                   'conv2d_294[0][0]']
#
#  normalization_94 (Normalizatio  (None, 256, 256, 6)  13         ['multi_head_attention_94[0][0]']
#  n)
#
#  conv2d_295 (Conv2D)            (None, 256, 256, 12  84          ['normalization_94[0][0]']
#                                 )
#
#  depthwise_conv2d_191 (Depthwis  (None, 256, 256, 12  120        ['conv2d_295[0][0]']
#  eConv2D)                       )
#
#  conv2d_296 (Conv2D)            (None, 256, 256, 12  84          ['normalization_94[0][0]']
#                                 )
#
#  tf.nn.gelu_94 (TFOpLambda)     (None, 256, 256, 12  0           ['depthwise_conv2d_191[0][0]']
#                                 )
#
#  depthwise_conv2d_192 (Depthwis  (None, 256, 256, 12  120        ['conv2d_296[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_94 (TFOpLambd  (None, 256, 256, 12  0          ['tf.nn.gelu_94[0][0]',
#  a)                             )                                 'depthwise_conv2d_192[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 256, 256, 6)  78          ['tf.math.multiply_94[0][0]']
#
#  multi_head_attention_95 (Multi  (None, 256, 256, 6)  114        ['conv2d_297[0][0]',
#  HeadAttention)                                                   'conv2d_297[0][0]']
#
#  normalization_95 (Normalizatio  (None, 256, 256, 6)  13         ['multi_head_attention_95[0][0]']
#  n)
#
#  conv2d_298 (Conv2D)            (None, 256, 256, 12  84          ['normalization_95[0][0]']
#                                 )
#
#  depthwise_conv2d_193 (Depthwis  (None, 256, 256, 12  120        ['conv2d_298[0][0]']
#  eConv2D)                       )
#
#  conv2d_299 (Conv2D)            (None, 256, 256, 12  84          ['normalization_95[0][0]']
#                                 )
#
#  tf.nn.gelu_95 (TFOpLambda)     (None, 256, 256, 12  0           ['depthwise_conv2d_193[0][0]']
#                                 )
#
#  depthwise_conv2d_194 (Depthwis  (None, 256, 256, 12  120        ['conv2d_299[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_95 (TFOpLambd  (None, 256, 256, 12  0          ['tf.nn.gelu_95[0][0]',
#  a)                             )                                 'depthwise_conv2d_194[0][0]']
#
#  conv2d_300 (Conv2D)            (None, 256, 256, 6)  78          ['tf.math.multiply_95[0][0]']
#
#  multi_head_attention_96 (Multi  (None, 256, 256, 6)  114        ['conv2d_300[0][0]',
#  HeadAttention)                                                   'conv2d_300[0][0]']
#
#  normalization_96 (Normalizatio  (None, 256, 256, 6)  13         ['multi_head_attention_96[0][0]']
#  n)
#
#  conv2d_301 (Conv2D)            (None, 256, 256, 12  84          ['normalization_96[0][0]']
#                                 )
#
#  depthwise_conv2d_195 (Depthwis  (None, 256, 256, 12  120        ['conv2d_301[0][0]']
#  eConv2D)                       )
#
#  conv2d_302 (Conv2D)            (None, 256, 256, 12  84          ['normalization_96[0][0]']
#                                 )
#
#  tf.nn.gelu_96 (TFOpLambda)     (None, 256, 256, 12  0           ['depthwise_conv2d_195[0][0]']
#                                 )
#
#  depthwise_conv2d_196 (Depthwis  (None, 256, 256, 12  120        ['conv2d_302[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_96 (TFOpLambd  (None, 256, 256, 12  0          ['tf.nn.gelu_96[0][0]',
#  a)                             )                                 'depthwise_conv2d_196[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 256, 256, 6)  78          ['tf.math.multiply_96[0][0]']
#
#  multi_head_attention_97 (Multi  (None, 256, 256, 6)  114        ['conv2d_303[0][0]',
#  HeadAttention)                                                   'conv2d_303[0][0]']
#
#  normalization_97 (Normalizatio  (None, 256, 256, 6)  13         ['multi_head_attention_97[0][0]']
#  n)
#
#  conv2d_304 (Conv2D)            (None, 256, 256, 12  84          ['normalization_97[0][0]']
#                                 )
#
#  depthwise_conv2d_197 (Depthwis  (None, 256, 256, 12  120        ['conv2d_304[0][0]']
#  eConv2D)                       )
#
#  conv2d_305 (Conv2D)            (None, 256, 256, 12  84          ['normalization_97[0][0]']
#                                 )
#
#  tf.nn.gelu_97 (TFOpLambda)     (None, 256, 256, 12  0           ['depthwise_conv2d_197[0][0]']
#                                 )
#
#  depthwise_conv2d_198 (Depthwis  (None, 256, 256, 12  120        ['conv2d_305[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_97 (TFOpLambd  (None, 256, 256, 12  0          ['tf.nn.gelu_97[0][0]',
#  a)                             )                                 'depthwise_conv2d_198[0][0]']
#
#  conv2d_306 (Conv2D)            (None, 256, 256, 6)  78          ['tf.math.multiply_97[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 256, 256, 12  84          ['conv2d_306[0][0]']
#                                 )
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 128, 128, 12  0          ['conv2d_307[0][0]']
#                                 )
#
#  multi_head_attention_98 (Multi  (None, 128, 128, 12  420        ['max_pooling2d_7[0][0]',
#  HeadAttention)                 )                                 'max_pooling2d_7[0][0]']
#
#  normalization_98 (Normalizatio  (None, 128, 128, 12  25         ['multi_head_attention_98[0][0]']
#  n)                             )
#
#  conv2d_308 (Conv2D)            (None, 128, 128, 24  312         ['normalization_98[0][0]']
#                                 )
#
#  depthwise_conv2d_199 (Depthwis  (None, 128, 128, 24  240        ['conv2d_308[0][0]']
#  eConv2D)                       )
#
#  conv2d_309 (Conv2D)            (None, 128, 128, 24  312         ['normalization_98[0][0]']
#                                 )
#
#  tf.nn.gelu_98 (TFOpLambda)     (None, 128, 128, 24  0           ['depthwise_conv2d_199[0][0]']
#                                 )
#
#  depthwise_conv2d_200 (Depthwis  (None, 128, 128, 24  240        ['conv2d_309[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_98 (TFOpLambd  (None, 128, 128, 24  0          ['tf.nn.gelu_98[0][0]',
#  a)                             )                                 'depthwise_conv2d_200[0][0]']
#
#  conv2d_310 (Conv2D)            (None, 128, 128, 12  300         ['tf.math.multiply_98[0][0]']
#                                 )
#
#  multi_head_attention_99 (Multi  (None, 128, 128, 12  420        ['conv2d_310[0][0]',
#  HeadAttention)                 )                                 'conv2d_310[0][0]']
#
#  normalization_99 (Normalizatio  (None, 128, 128, 12  25         ['multi_head_attention_99[0][0]']
#  n)                             )
#
#  conv2d_311 (Conv2D)            (None, 128, 128, 24  312         ['normalization_99[0][0]']
#                                 )
#
#  depthwise_conv2d_201 (Depthwis  (None, 128, 128, 24  240        ['conv2d_311[0][0]']
#  eConv2D)                       )
#
#  conv2d_312 (Conv2D)            (None, 128, 128, 24  312         ['normalization_99[0][0]']
#                                 )
#
#  tf.nn.gelu_99 (TFOpLambda)     (None, 128, 128, 24  0           ['depthwise_conv2d_201[0][0]']
#                                 )
#
#  depthwise_conv2d_202 (Depthwis  (None, 128, 128, 24  240        ['conv2d_312[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_99 (TFOpLambd  (None, 128, 128, 24  0          ['tf.nn.gelu_99[0][0]',
#  a)                             )                                 'depthwise_conv2d_202[0][0]']
#
#  conv2d_313 (Conv2D)            (None, 128, 128, 12  300         ['tf.math.multiply_99[0][0]']
#                                 )
#
#  multi_head_attention_100 (Mult  (None, 128, 128, 12  420        ['conv2d_313[0][0]',
#  iHeadAttention)                )                                 'conv2d_313[0][0]']
#
#  normalization_100 (Normalizati  (None, 128, 128, 12  25         ['multi_head_attention_100[0][0]'
#  on)                            )                                ]
#
#  conv2d_314 (Conv2D)            (None, 128, 128, 24  312         ['normalization_100[0][0]']
#                                 )
#
#  depthwise_conv2d_203 (Depthwis  (None, 128, 128, 24  240        ['conv2d_314[0][0]']
#  eConv2D)                       )
#
#  conv2d_315 (Conv2D)            (None, 128, 128, 24  312         ['normalization_100[0][0]']
#                                 )
#
#  tf.nn.gelu_100 (TFOpLambda)    (None, 128, 128, 24  0           ['depthwise_conv2d_203[0][0]']
#                                 )
#
#  depthwise_conv2d_204 (Depthwis  (None, 128, 128, 24  240        ['conv2d_315[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_100 (TFOpLamb  (None, 128, 128, 24  0          ['tf.nn.gelu_100[0][0]',
#  da)                            )                                 'depthwise_conv2d_204[0][0]']
#
#  conv2d_316 (Conv2D)            (None, 128, 128, 12  300         ['tf.math.multiply_100[0][0]']
#                                 )
#
#  multi_head_attention_101 (Mult  (None, 128, 128, 12  420        ['conv2d_316[0][0]',
#  iHeadAttention)                )                                 'conv2d_316[0][0]']
#
#  normalization_101 (Normalizati  (None, 128, 128, 12  25         ['multi_head_attention_101[0][0]'
#  on)                            )                                ]
#
#  conv2d_317 (Conv2D)            (None, 128, 128, 24  312         ['normalization_101[0][0]']
#                                 )
#
#  depthwise_conv2d_205 (Depthwis  (None, 128, 128, 24  240        ['conv2d_317[0][0]']
#  eConv2D)                       )
#
#  conv2d_318 (Conv2D)            (None, 128, 128, 24  312         ['normalization_101[0][0]']
#                                 )
#
#  tf.nn.gelu_101 (TFOpLambda)    (None, 128, 128, 24  0           ['depthwise_conv2d_205[0][0]']
#                                 )
#
#  depthwise_conv2d_206 (Depthwis  (None, 128, 128, 24  240        ['conv2d_318[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_101 (TFOpLamb  (None, 128, 128, 24  0          ['tf.nn.gelu_101[0][0]',
#  da)                            )                                 'depthwise_conv2d_206[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 128, 128, 12  300         ['tf.math.multiply_101[0][0]']
#                                 )
#
#  multi_head_attention_102 (Mult  (None, 128, 128, 12  420        ['conv2d_319[0][0]',
#  iHeadAttention)                )                                 'conv2d_319[0][0]']
#
#  normalization_102 (Normalizati  (None, 128, 128, 12  25         ['multi_head_attention_102[0][0]'
#  on)                            )                                ]
#
#  conv2d_320 (Conv2D)            (None, 128, 128, 24  312         ['normalization_102[0][0]']
#                                 )
#
#  depthwise_conv2d_207 (Depthwis  (None, 128, 128, 24  240        ['conv2d_320[0][0]']
#  eConv2D)                       )
#
#  conv2d_321 (Conv2D)            (None, 128, 128, 24  312         ['normalization_102[0][0]']
#                                 )
#
#  tf.nn.gelu_102 (TFOpLambda)    (None, 128, 128, 24  0           ['depthwise_conv2d_207[0][0]']
#                                 )
#
#  depthwise_conv2d_208 (Depthwis  (None, 128, 128, 24  240        ['conv2d_321[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_102 (TFOpLamb  (None, 128, 128, 24  0          ['tf.nn.gelu_102[0][0]',
#  da)                            )                                 'depthwise_conv2d_208[0][0]']
#
#  conv2d_322 (Conv2D)            (None, 128, 128, 12  300         ['tf.math.multiply_102[0][0]']
#                                 )
#
#  multi_head_attention_103 (Mult  (None, 128, 128, 12  420        ['conv2d_322[0][0]',
#  iHeadAttention)                )                                 'conv2d_322[0][0]']
#
#  normalization_103 (Normalizati  (None, 128, 128, 12  25         ['multi_head_attention_103[0][0]'
#  on)                            )                                ]
#
#  conv2d_323 (Conv2D)            (None, 128, 128, 24  312         ['normalization_103[0][0]']
#                                 )
#
#  depthwise_conv2d_209 (Depthwis  (None, 128, 128, 24  240        ['conv2d_323[0][0]']
#  eConv2D)                       )
#
#  conv2d_324 (Conv2D)            (None, 128, 128, 24  312         ['normalization_103[0][0]']
#                                 )
#
#  tf.nn.gelu_103 (TFOpLambda)    (None, 128, 128, 24  0           ['depthwise_conv2d_209[0][0]']
#                                 )
#
#  depthwise_conv2d_210 (Depthwis  (None, 128, 128, 24  240        ['conv2d_324[0][0]']
#  eConv2D)                       )
#
#  tf.math.multiply_103 (TFOpLamb  (None, 128, 128, 24  0          ['tf.nn.gelu_103[0][0]',
#  da)                            )                                 'depthwise_conv2d_210[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 128, 128, 12  300         ['tf.math.multiply_103[0][0]']
#                                 )
#
#  conv2d_326 (Conv2D)            (None, 128, 128, 24  312         ['conv2d_325[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 24)  0           ['conv2d_326[0][0]']
#
#  multi_head_attention_104 (Mult  (None, 64, 64, 24)  1608        ['max_pooling2d_8[0][0]',
#  iHeadAttention)                                                  'max_pooling2d_8[0][0]']
#
#  normalization_104 (Normalizati  (None, 64, 64, 24)  49          ['multi_head_attention_104[0][0]'
#  on)                                                             ]
#
#  conv2d_327 (Conv2D)            (None, 64, 64, 48)   1200        ['normalization_104[0][0]']
#
#  depthwise_conv2d_211 (Depthwis  (None, 64, 64, 48)  480         ['conv2d_327[0][0]']
#  eConv2D)
#
#  conv2d_328 (Conv2D)            (None, 64, 64, 48)   1200        ['normalization_104[0][0]']
#
#  tf.nn.gelu_104 (TFOpLambda)    (None, 64, 64, 48)   0           ['depthwise_conv2d_211[0][0]']
#
#  depthwise_conv2d_212 (Depthwis  (None, 64, 64, 48)  480         ['conv2d_328[0][0]']
#  eConv2D)
#
#  tf.math.multiply_104 (TFOpLamb  (None, 64, 64, 48)  0           ['tf.nn.gelu_104[0][0]',
#  da)                                                              'depthwise_conv2d_212[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 64, 64, 24)   1176        ['tf.math.multiply_104[0][0]']
#
#  multi_head_attention_105 (Mult  (None, 64, 64, 24)  1608        ['conv2d_329[0][0]',
#  iHeadAttention)                                                  'conv2d_329[0][0]']
#
#  normalization_105 (Normalizati  (None, 64, 64, 24)  49          ['multi_head_attention_105[0][0]'
#  on)                                                             ]
#
#  conv2d_330 (Conv2D)            (None, 64, 64, 48)   1200        ['normalization_105[0][0]']
#
#  depthwise_conv2d_213 (Depthwis  (None, 64, 64, 48)  480         ['conv2d_330[0][0]']
#  eConv2D)
#
#  conv2d_331 (Conv2D)            (None, 64, 64, 48)   1200        ['normalization_105[0][0]']
#
#  tf.nn.gelu_105 (TFOpLambda)    (None, 64, 64, 48)   0           ['depthwise_conv2d_213[0][0]']
#
#  depthwise_conv2d_214 (Depthwis  (None, 64, 64, 48)  480         ['conv2d_331[0][0]']
#  eConv2D)
#
#  tf.math.multiply_105 (TFOpLamb  (None, 64, 64, 48)  0           ['tf.nn.gelu_105[0][0]',
#  da)                                                              'depthwise_conv2d_214[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 64, 64, 24)   1176        ['tf.math.multiply_105[0][0]']
#
#  multi_head_attention_106 (Mult  (None, 64, 64, 24)  1608        ['conv2d_332[0][0]',
#  iHeadAttention)                                                  'conv2d_332[0][0]']
#
#  normalization_106 (Normalizati  (None, 64, 64, 24)  49          ['multi_head_attention_106[0][0]'
# ...
#  eConv2D)
#
#  conv2d_394 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_125[0][0]']
#
#  tf.nn.gelu_125 (TFOpLambda)    (None, 512, 512, 6)  0           ['depthwise_conv2d_253[0][0]']
#
#  depthwise_conv2d_254 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_394[0][0]']
#  eConv2D)
#
#  tf.math.multiply_125 (TFOpLamb  (None, 512, 512, 6)  0          ['tf.nn.gelu_125[0][0]',
#  da)                                                              'depthwise_conv2d_254[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_125[0][0]']
#
#  multi_head_attention_126 (Mult  (None, 512, 512, 3)  33         ['conv2d_395[0][0]',
#  iHeadAttention)                                                  'conv2d_395[0][0]']
#
#  normalization_126 (Normalizati  (None, 512, 512, 3)  7          ['multi_head_attention_126[0][0]'
#  on)                                                             ]
#
#  conv2d_396 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_126[0][0]']
#
#  depthwise_conv2d_255 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_396[0][0]']
#  eConv2D)
#
#  conv2d_397 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_126[0][0]']
#
#  tf.nn.gelu_126 (TFOpLambda)    (None, 512, 512, 6)  0           ['depthwise_conv2d_255[0][0]']
#
#  depthwise_conv2d_256 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_397[0][0]']
#  eConv2D)
#
#  tf.math.multiply_126 (TFOpLamb  (None, 512, 512, 6)  0          ['tf.nn.gelu_126[0][0]',
#  da)                                                              'depthwise_conv2d_256[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_126[0][0]']
#
#  multi_head_attention_127 (Mult  (None, 512, 512, 3)  33         ['conv2d_398[0][0]',
#  iHeadAttention)                                                  'conv2d_398[0][0]']
#
#  normalization_127 (Normalizati  (None, 512, 512, 3)  7          ['multi_head_attention_127[0][0]'
#  on)                                                             ]
#
#  conv2d_399 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_127[0][0]']
#
#  depthwise_conv2d_257 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_399[0][0]']
#  eConv2D)
#
#  conv2d_400 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_127[0][0]']
#
#  tf.nn.gelu_127 (TFOpLambda)    (None, 512, 512, 6)  0           ['depthwise_conv2d_257[0][0]']
#
#  depthwise_conv2d_258 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_400[0][0]']
#  eConv2D)
#
#  tf.math.multiply_127 (TFOpLamb  (None, 512, 512, 6)  0          ['tf.nn.gelu_127[0][0]',
#  da)                                                              'depthwise_conv2d_258[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_127[0][0]']
#
#  multi_head_attention_128 (Mult  (None, 512, 512, 3)  33         ['conv2d_401[0][0]',
#  iHeadAttention)                                                  'conv2d_401[0][0]']
#
#  normalization_128 (Normalizati  (None, 512, 512, 3)  7          ['multi_head_attention_128[0][0]'
#  on)                                                             ]
#
#  conv2d_402 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_128[0][0]']
#
#  depthwise_conv2d_259 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_402[0][0]']
#  eConv2D)
#
#  conv2d_403 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_128[0][0]']
#
#  tf.nn.gelu_128 (TFOpLambda)    (None, 512, 512, 6)  0           ['depthwise_conv2d_259[0][0]']
#
#  depthwise_conv2d_260 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_403[0][0]']
#  eConv2D)
#
#  tf.math.multiply_128 (TFOpLamb  (None, 512, 512, 6)  0          ['tf.nn.gelu_128[0][0]',
#  da)                                                              'depthwise_conv2d_260[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_128[0][0]']
#
#  multi_head_attention_129 (Mult  (None, 512, 512, 3)  33         ['conv2d_404[0][0]',
#  iHeadAttention)                                                  'conv2d_404[0][0]']
#
#  normalization_129 (Normalizati  (None, 512, 512, 3)  7          ['multi_head_attention_129[0][0]'
#  on)                                                             ]
#
#  conv2d_405 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_129[0][0]']
#
#  depthwise_conv2d_261 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_405[0][0]']
#  eConv2D)
#
#  conv2d_406 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_129[0][0]']
#
#  tf.nn.gelu_129 (TFOpLambda)    (None, 512, 512, 6)  0           ['depthwise_conv2d_261[0][0]']
#
#  depthwise_conv2d_262 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_406[0][0]']
#  eConv2D)
#
#  tf.math.multiply_129 (TFOpLamb  (None, 512, 512, 6)  0          ['tf.nn.gelu_129[0][0]',
#  da)                                                              'depthwise_conv2d_262[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_129[0][0]']
#
#  multi_head_attention_130 (Mult  (None, 512, 512, 3)  33         ['conv2d_407[0][0]',
#  iHeadAttention)                                                  'conv2d_407[0][0]']
#
#  normalization_130 (Normalizati  (None, 512, 512, 3)  7          ['multi_head_attention_130[0][0]'
#  on)                                                             ]
#
#  conv2d_408 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_130[0][0]']
#
#  depthwise_conv2d_263 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_408[0][0]']
#  eConv2D)
#
#  conv2d_409 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_130[0][0]']
#
#  tf.nn.gelu_130 (TFOpLambda)    (None, 512, 512, 6)  0           ['depthwise_conv2d_263[0][0]']
#
#  depthwise_conv2d_264 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_409[0][0]']
#  eConv2D)
#
#  tf.math.multiply_130 (TFOpLamb  (None, 512, 512, 6)  0          ['tf.nn.gelu_130[0][0]',
#  da)                                                              'depthwise_conv2d_264[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_130[0][0]']
#
#  multi_head_attention_131 (Mult  (None, 512, 512, 3)  33         ['conv2d_410[0][0]',
#  iHeadAttention)                                                  'conv2d_410[0][0]']
#
#  normalization_131 (Normalizati  (None, 512, 512, 3)  7          ['multi_head_attention_131[0][0]'
#  on)                                                             ]
#
#  conv2d_411 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_131[0][0]']
#
#  depthwise_conv2d_265 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_411[0][0]']
#  eConv2D)
#
#  conv2d_412 (Conv2D)            (None, 512, 512, 6)  24          ['normalization_131[0][0]']
#
#  tf.nn.gelu_131 (TFOpLambda)    (None, 512, 512, 6)  0           ['depthwise_conv2d_265[0][0]']
#
#  depthwise_conv2d_266 (Depthwis  (None, 512, 512, 6)  60         ['conv2d_412[0][0]']
#  eConv2D)
#
#  tf.math.multiply_131 (TFOpLamb  (None, 512, 512, 6)  0          ['tf.nn.gelu_131[0][0]',
#  da)                                                              'depthwise_conv2d_266[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 512, 512, 3)  21          ['tf.math.multiply_131[0][0]']
#
#  depthwise_conv2d_267 (Depthwis  (None, 512, 512, 3)  30         ['conv2d_413[0][0]']
#  eConv2D)
#
#  tf.__operators__.add_134 (TFOp  (None, 512, 512, 3)  0          ['input_3[0][0]',
#  Lambda)                                                          'depthwise_conv2d_267[0][0]']
#
# ==================================================================================================
# Total params: 86,138
# Trainable params: 85,206
# Non-trainable params: 932
# __________________________________________________________________________________________________

# %%
image_path = '/content/drive/MyDrive/source2'
models_path = '/content/drive/MyDrive/models/'

# %%
import itertools
import tensorflow as tf
from speedup import generate_out_images3
import numpy as np
from random import randint, uniform
import imageio
import time


source_num = 2799
dim = 512
stationary_defocus = 0.05


def gen():
    while True:

        layer1_number = randint(0, source_num)
        layer2_number = randint(0, source_num)
        layer3_number = randint(0, source_num)

        src1 = imageio.imread(image_path + '/image' + str(layer1_number).zfill(4) + '.png')
        src2 = imageio.imread(image_path + '/image' + str(layer2_number).zfill(4) + '.png')
        src3 = imageio.imread(image_path + '/image' + str(layer3_number).zfill(4) + '.png')
        src = np.zeros((dim, dim, m), np.double)
        src[:, :, 0] = src1[:, :, 0]
        src[:, :, 1] = src2[:, :, 0]
        src[:, :, 2] = src3[:, :, 0]
        src = src - np.amin(src)
        src = src / np.amax(src)

        w = uniform(0.05, 0.5) 
        
        a_10 = uniform(-1e3, 1e3)
        a_01 = uniform(-1e3, 1e3)
        b_20 = uniform(1, 1.5)
        b_11 = uniform(-0.1, 0.1)
        b_02 = uniform(1, 1.5)
        c_30 = uniform(-1.5e-6, 1.5e-6)
        c_21 = uniform(-2e-6, 2e-6)
        c_12 = uniform(-2e-6, 2e-6)
        c_03 = uniform(-1.5e-6, 1.5e-6)

        out = generate_out_images3(dim, m, w, stationary_defocus, a_10, a_01, b_20, b_11, b_02, c_30, c_21, c_12, c_03, src)[1]
        out = out / np.amax(out)

        #src[src > 0] = 1.

        yield (out, src)


tr_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .batch(batch_size=2).prefetch(buffer_size=8)

val_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .take(count=128).cache().batch(batch_size=2)


opt = tf.keras.optimizers.Adam()

save_best_callback = tf.keras.callbacks.ModelCheckpoint(models_path + 'bestmodel_cnn_transformer.hdf5',
                                                        save_weights_only=True,save_best_only=True, verbose=True)
csv_logger_callback = tf.keras.callbacks.CSVLogger(models_path + 'log_cnn_transformer.csv')
lr_reduce_callback = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, min_delta=5e-4, patience=5)
early_stop_callback = tf.keras.callbacks.EarlyStopping(patience=25)

model_instance = constructModel()
model_instance.compile(loss='mse', optimizer=opt, metrics=['binary_crossentropy', 'mse'])
model_instance.fit(x=tr_dataset, validation_data=val_dataset, verbose=1, validation_steps=64,
                   steps_per_epoch=256, epochs=200,
                   callbacks=[save_best_callback, csv_logger_callback, lr_reduce_callback, early_stop_callback])
