# %%
import speedup
import tensorflow as tf
import numpy as np
import tensorflow as tf
import random
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)

# %%
def conv2d_bn(x, filters, num_row, num_col, padding = 'same', strides = (1, 1), activation = 'relu', name = None):

    x = tf.keras.layers.Conv2D(filters, (num_row, num_col), strides = strides, padding = padding, use_bias = False)(x)
    x = tf.keras.layers.BatchNormalization(axis = 3, scale = False)(x)

    if(activation == None):
        return x

    x = tf.keras.layers.Activation(activation, name = name)(x)

    return x

# %%
def trans_conv2d_bn(x, filters, num_row, num_col, padding = 'same', strides = (2, 2), name = None):

    x = tf.keras.layers.Conv2DTranspose(filters, (num_row, num_col), strides = strides, padding = padding)(x)
    x = tf.keras.layers.BatchNormalization(axis = 3, scale = False)(x)
    
    return x

# %%
def DCBlock(U, inp, alpha = 1.67):

    W = alpha * U


    conv3x3_1 = conv2d_bn(inp, int(W*0.167), 3, 3,
                        activation='relu', padding='same')

    conv5x5_1 = conv2d_bn(conv3x3_1, int(W*0.333), 3, 3,
                        activation='relu', padding='same')

    conv7x7_1 = conv2d_bn(conv5x5_1, int(W*0.5), 3, 3,
                        activation='relu', padding='same')

    out1 = tf.keras.layers.concatenate([conv3x3_1, conv5x5_1, conv7x7_1], axis=3)
    out1 = tf.keras.layers.BatchNormalization(axis=3)(out1)
    

    conv3x3_2 = conv2d_bn(inp, int(W*0.167), 3, 3,
                        activation='relu', padding='same')

    conv5x5_2 = conv2d_bn(conv3x3_2, int(W*0.333), 3, 3,
                        activation='relu', padding='same')

    conv7x7_2 = conv2d_bn(conv5x5_2, int(W*0.5), 3, 3,
                        activation='relu', padding='same')
    
    out2 = tf.keras.layers.concatenate([conv3x3_2, conv5x5_2, conv7x7_2], axis=3)
    out2 = tf.keras.layers.BatchNormalization(axis=3)(out2)


    out = tf.keras.layers.Add()([out1, out2])
    out = tf.keras.layers.Activation('relu')(out)
    out = tf.keras.layers.BatchNormalization(axis=3)(out)

    return out

# %%
def ResPath(filters, length, inp):

    shortcut = inp
    shortcut = conv2d_bn(shortcut, filters, 1, 1,
                         activation=None, padding='same')

    out = conv2d_bn(inp, filters, 3, 3, activation='relu', padding='same')

    out = tf.keras.layers.Add()([shortcut, out])
    out = tf.keras.layers.Activation('relu')(out)
    out = tf.keras.layers.BatchNormalization(axis=3)(out)

    for i in range(length-1):

        shortcut = out
        shortcut = conv2d_bn(shortcut, filters, 1, 1,
                             activation=None, padding='same')

        out = conv2d_bn(out, filters, 3, 3, activation='relu', padding='same')

        out = tf.keras.layers.Add()([shortcut, out])
        out = tf.keras.layers.Activation('relu')(out)
        out = tf.keras.layers.BatchNormalization(axis=3)(out)

    return out

# %%
imageSize = 512
m = 3

def constructModel():
    inputs = tf.keras.layers.Input((imageSize, imageSize, m))

    dcblock1 = DCBlock(32, inputs)
    pool1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(dcblock1)
    dcblock1 = ResPath(32, 4, dcblock1)

    dcblock2 = DCBlock(32*2, pool1)
    pool2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(dcblock2)
    dcblock2 = ResPath(32*2, 3, dcblock2)

    dcblock3 = DCBlock(32*4, pool2)
    pool3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(dcblock3)
    dcblock3 = ResPath(32*4, 2, dcblock3)

    dcblock4 = DCBlock(32*8, pool3)
    pool4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(dcblock4)
    dcblock4 = ResPath(32*8, 1, dcblock4)

    dcblock5 = DCBlock(32*16, pool4)

    up6 = tf.keras.layers.concatenate([tf.keras.layers.Conv2DTranspose(
        32*8, (2, 2), strides=(2, 2), padding='same')(dcblock5), dcblock4], axis=3)
    dcblock6 = DCBlock(32*8, up6)

    up7 = tf.keras.layers.concatenate([tf.keras.layers.Conv2DTranspose(
        32*4, (2, 2), strides=(2, 2), padding='same')(dcblock6), dcblock3], axis=3)
    dcblock7 = DCBlock(32*4, up7)

    up8 = tf.keras.layers.concatenate([tf.keras.layers.Conv2DTranspose(
        32*2, (2, 2), strides=(2, 2), padding='same')(dcblock7), dcblock2], axis=3)
    dcblock8 = DCBlock(32*2, up8)

    up9 = tf.keras.layers.concatenate([tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(
        2, 2), padding='same')(dcblock8), dcblock1], axis=3)
    dcblock9 = DCBlock(32, up9)

    conv10 = conv2d_bn(dcblock9, 3, 1, 1, activation='sigmoid')
    
    model = tf.keras.Model(inputs=[inputs], outputs=[conv10])

    return model

# %%
model_instance = constructModel()
model_instance.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_75 (Conv2D)             (None, 512, 512, 8)  216         ['input_2[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 512, 512, 8)  216         ['input_2[0][0]']
#
#  batch_normalization_112 (Batch  (None, 512, 512, 8)  24         ['conv2d_75[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 512, 512, 8)  24         ['conv2d_78[0][0]']
#  Normalization)
#
#  activation_84 (Activation)     (None, 512, 512, 8)  0           ['batch_normalization_112[0][0]']
#
#  activation_87 (Activation)     (None, 512, 512, 8)  0           ['batch_normalization_116[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 512, 512, 17  1224        ['activation_84[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 512, 512, 17  1224        ['activation_87[0][0]']
#                                 )
#
#  batch_normalization_113 (Batch  (None, 512, 512, 17  51         ['conv2d_76[0][0]']
#  Normalization)                 )
#
#  batch_normalization_117 (Batch  (None, 512, 512, 17  51         ['conv2d_79[0][0]']
#  Normalization)                 )
#
#  activation_85 (Activation)     (None, 512, 512, 17  0           ['batch_normalization_113[0][0]']
#                                 )
#
#  activation_88 (Activation)     (None, 512, 512, 17  0           ['batch_normalization_117[0][0]']
#                                 )
#
#  conv2d_77 (Conv2D)             (None, 512, 512, 26  3978        ['activation_85[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 512, 512, 26  3978        ['activation_88[0][0]']
#                                 )
#
#  batch_normalization_114 (Batch  (None, 512, 512, 26  78         ['conv2d_77[0][0]']
#  Normalization)                 )
#
#  batch_normalization_118 (Batch  (None, 512, 512, 26  78         ['conv2d_80[0][0]']
#  Normalization)                 )
#
#  activation_86 (Activation)     (None, 512, 512, 26  0           ['batch_normalization_114[0][0]']
#                                 )
#
#  activation_89 (Activation)     (None, 512, 512, 26  0           ['batch_normalization_118[0][0]']
#                                 )
#
#  concatenate_22 (Concatenate)   (None, 512, 512, 51  0           ['activation_84[0][0]',
#                                 )                                 'activation_85[0][0]',
#                                                                   'activation_86[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 512, 512, 51  0           ['activation_87[0][0]',
#                                 )                                 'activation_88[0][0]',
#                                                                   'activation_89[0][0]']
#
#  batch_normalization_115 (Batch  (None, 512, 512, 51  204        ['concatenate_22[0][0]']
#  Normalization)                 )
#
#  batch_normalization_119 (Batch  (None, 512, 512, 51  204        ['concatenate_23[0][0]']
#  Normalization)                 )
#
#  add_19 (Add)                   (None, 512, 512, 51  0           ['batch_normalization_115[0][0]',
#                                 )                                 'batch_normalization_119[0][0]']
#
#  activation_90 (Activation)     (None, 512, 512, 51  0           ['add_19[0][0]']
#                                 )
#
#  batch_normalization_120 (Batch  (None, 512, 512, 51  204        ['activation_90[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 51  0          ['batch_normalization_120[0][0]']
#                                 )
#
#  conv2d_89 (Conv2D)             (None, 256, 256, 17  7803        ['max_pooling2d_4[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 256, 256, 17  7803        ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_133 (Batch  (None, 256, 256, 17  51         ['conv2d_89[0][0]']
#  Normalization)                 )
#
#  batch_normalization_137 (Batch  (None, 256, 256, 17  51         ['conv2d_92[0][0]']
#  Normalization)                 )
#
#  activation_99 (Activation)     (None, 256, 256, 17  0           ['batch_normalization_133[0][0]']
#                                 )
#
#  activation_102 (Activation)    (None, 256, 256, 17  0           ['batch_normalization_137[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 256, 256, 35  5355        ['activation_99[0][0]']
#                                 )
#
#  conv2d_93 (Conv2D)             (None, 256, 256, 35  5355        ['activation_102[0][0]']
#                                 )
#
#  batch_normalization_134 (Batch  (None, 256, 256, 35  105        ['conv2d_90[0][0]']
#  Normalization)                 )
#
#  batch_normalization_138 (Batch  (None, 256, 256, 35  105        ['conv2d_93[0][0]']
#  Normalization)                 )
#
#  activation_100 (Activation)    (None, 256, 256, 35  0           ['batch_normalization_134[0][0]']
#                                 )
#
#  activation_103 (Activation)    (None, 256, 256, 35  0           ['batch_normalization_138[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 256, 256, 53  16695       ['activation_100[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 256, 256, 53  16695       ['activation_103[0][0]']
#                                 )
#
#  batch_normalization_135 (Batch  (None, 256, 256, 53  159        ['conv2d_91[0][0]']
#  Normalization)                 )
#
#  batch_normalization_139 (Batch  (None, 256, 256, 53  159        ['conv2d_94[0][0]']
#  Normalization)                 )
#
#  activation_101 (Activation)    (None, 256, 256, 53  0           ['batch_normalization_135[0][0]']
#                                 )
#
#  activation_104 (Activation)    (None, 256, 256, 53  0           ['batch_normalization_139[0][0]']
#                                 )
#
#  concatenate_24 (Concatenate)   (None, 256, 256, 10  0           ['activation_99[0][0]',
#                                 5)                                'activation_100[0][0]',
#                                                                   'activation_101[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 256, 256, 10  0           ['activation_102[0][0]',
#                                 5)                                'activation_103[0][0]',
#                                                                   'activation_104[0][0]']
#
#  batch_normalization_136 (Batch  (None, 256, 256, 10  420        ['concatenate_24[0][0]']
#  Normalization)                 5)
#
#  batch_normalization_140 (Batch  (None, 256, 256, 10  420        ['concatenate_25[0][0]']
#  Normalization)                 5)
#
#  add_24 (Add)                   (None, 256, 256, 10  0           ['batch_normalization_136[0][0]',
#                                 5)                                'batch_normalization_140[0][0]']
#
#  activation_105 (Activation)    (None, 256, 256, 10  0           ['add_24[0][0]']
#                                 5)
#
#  batch_normalization_141 (Batch  (None, 256, 256, 10  420        ['activation_105[0][0]']
#  Normalization)                 5)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 10  0          ['batch_normalization_141[0][0]']
#                                 5)
#
#  conv2d_101 (Conv2D)            (None, 128, 128, 35  33075       ['max_pooling2d_5[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 128, 128, 35  33075       ['max_pooling2d_5[0][0]']
#                                 )
#
#  batch_normalization_151 (Batch  (None, 128, 128, 35  105        ['conv2d_101[0][0]']
#  Normalization)                 )
#
#  batch_normalization_155 (Batch  (None, 128, 128, 35  105        ['conv2d_104[0][0]']
#  Normalization)                 )
#
#  activation_112 (Activation)    (None, 128, 128, 35  0           ['batch_normalization_151[0][0]']
#                                 )
#
#  activation_115 (Activation)    (None, 128, 128, 35  0           ['batch_normalization_155[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 128, 128, 71  22365       ['activation_112[0][0]']
#                                 )
#
#  conv2d_105 (Conv2D)            (None, 128, 128, 71  22365       ['activation_115[0][0]']
#                                 )
#
#  batch_normalization_152 (Batch  (None, 128, 128, 71  213        ['conv2d_102[0][0]']
#  Normalization)                 )
#
#  batch_normalization_156 (Batch  (None, 128, 128, 71  213        ['conv2d_105[0][0]']
#  Normalization)                 )
#
#  activation_113 (Activation)    (None, 128, 128, 71  0           ['batch_normalization_152[0][0]']
#                                 )
#
#  activation_116 (Activation)    (None, 128, 128, 71  0           ['batch_normalization_156[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 128, 128, 10  67734       ['activation_113[0][0]']
#                                 6)
#
#  conv2d_106 (Conv2D)            (None, 128, 128, 10  67734       ['activation_116[0][0]']
#                                 6)
#
#  batch_normalization_153 (Batch  (None, 128, 128, 10  318        ['conv2d_103[0][0]']
#  Normalization)                 6)
#
#  batch_normalization_157 (Batch  (None, 128, 128, 10  318        ['conv2d_106[0][0]']
#  Normalization)                 6)
#
#  activation_114 (Activation)    (None, 128, 128, 10  0           ['batch_normalization_153[0][0]']
#                                 6)
#
#  activation_117 (Activation)    (None, 128, 128, 10  0           ['batch_normalization_157[0][0]']
#                                 6)
#
#  concatenate_26 (Concatenate)   (None, 128, 128, 21  0           ['activation_112[0][0]',
#                                 2)                                'activation_113[0][0]',
#                                                                   'activation_114[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 128, 128, 21  0           ['activation_115[0][0]',
#                                 2)                                'activation_116[0][0]',
#                                                                   'activation_117[0][0]']
#
#  batch_normalization_154 (Batch  (None, 128, 128, 21  848        ['concatenate_26[0][0]']
#  Normalization)                 2)
#
#  batch_normalization_158 (Batch  (None, 128, 128, 21  848        ['concatenate_27[0][0]']
#  Normalization)                 2)
#
#  add_28 (Add)                   (None, 128, 128, 21  0           ['batch_normalization_154[0][0]',
#                                 2)                                'batch_normalization_158[0][0]']
#
#  activation_118 (Activation)    (None, 128, 128, 21  0           ['add_28[0][0]']
#                                 2)
#
#  batch_normalization_159 (Batch  (None, 128, 128, 21  848        ['activation_118[0][0]']
#  Normalization)                 2)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 212)  0          ['batch_normalization_159[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 64, 64, 71)   135468      ['max_pooling2d_6[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 64, 64, 71)   135468      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_166 (Batch  (None, 64, 64, 71)  213         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_170 (Batch  (None, 64, 64, 71)  213         ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 64, 64, 71)   0           ['batch_normalization_166[0][0]']
#
#  activation_126 (Activation)    (None, 64, 64, 71)   0           ['batch_normalization_170[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 64, 64, 142)  90738       ['activation_123[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 64, 64, 142)  90738       ['activation_126[0][0]']
#
#  batch_normalization_167 (Batch  (None, 64, 64, 142)  426        ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_171 (Batch  (None, 64, 64, 142)  426        ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 64, 64, 142)  0           ['batch_normalization_167[0][0]']
#
#  activation_127 (Activation)    (None, 64, 64, 142)  0           ['batch_normalization_171[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 64, 64, 213)  272214      ['activation_124[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 64, 64, 213)  272214      ['activation_127[0][0]']
#
#  batch_normalization_168 (Batch  (None, 64, 64, 213)  639        ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_172 (Batch  (None, 64, 64, 213)  639        ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 64, 64, 213)  0           ['batch_normalization_168[0][0]']
#
#  activation_128 (Activation)    (None, 64, 64, 213)  0           ['batch_normalization_172[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 64, 64, 426)  0           ['activation_123[0][0]',
#                                                                   'activation_124[0][0]',
#                                                                   'activation_125[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 64, 64, 426)  0           ['activation_126[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_128[0][0]']
#
#  batch_normalization_169 (Batch  (None, 64, 64, 426)  1704       ['concatenate_28[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 64, 64, 426)  1704       ['concatenate_29[0][0]']
#  Normalization)
#
#  add_31 (Add)                   (None, 64, 64, 426)  0           ['batch_normalization_169[0][0]',
#                                                                   'batch_normalization_173[0][0]']
#
#  activation_129 (Activation)    (None, 64, 64, 426)  0           ['add_31[0][0]']
#
#  batch_normalization_174 (Batch  (None, 64, 64, 426)  1704       ['activation_129[0][0]']
#  Normalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 426)  0          ['batch_normalization_174[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 32, 32, 142)  544428      ['max_pooling2d_7[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 32, 32, 142)  544428      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_178 (Batch  (None, 32, 32, 142)  426        ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 32, 32, 142)  426        ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 32, 32, 142)  0           ['batch_normalization_178[0][0]']
#
#  activation_135 (Activation)    (None, 32, 32, 142)  0           ['batch_normalization_182[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 32, 32, 284)  362952      ['activation_132[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 32, 32, 284)  362952      ['activation_135[0][0]']
#
#  batch_normalization_179 (Batch  (None, 32, 32, 284)  852        ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_183 (Batch  (None, 32, 32, 284)  852        ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 32, 32, 284)  0           ['batch_normalization_179[0][0]']
#
#  activation_136 (Activation)    (None, 32, 32, 284)  0           ['batch_normalization_183[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 32, 32, 427)  1091412     ['activation_133[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 32, 32, 427)  1091412     ['activation_136[0][0]']
#
#  batch_normalization_180 (Batch  (None, 32, 32, 427)  1281       ['conv2d_121[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 32, 32, 427)  1281       ['conv2d_124[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 32, 32, 427)  0           ['batch_normalization_180[0][0]']
#
#  activation_137 (Activation)    (None, 32, 32, 427)  0           ['batch_normalization_184[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 32, 32, 853)  0           ['activation_132[0][0]',
#                                                                   'activation_133[0][0]',
#                                                                   'activation_134[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 32, 32, 853)  0           ['activation_135[0][0]',
#                                                                   'activation_136[0][0]',
#                                                                   'activation_137[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 64, 64, 256)  981504      ['batch_normalization_174[0][0]']
#
#  batch_normalization_181 (Batch  (None, 32, 32, 853)  3412       ['concatenate_30[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 32, 32, 853)  3412       ['concatenate_31[0][0]']
#  Normalization)
#
#  conv2d_117 (Conv2D)            (None, 64, 64, 256)  109056      ['batch_normalization_174[0][0]']
#
#  batch_normalization_176 (Batch  (None, 64, 64, 256)  768        ['conv2d_118[0][0]']
#  Normalization)
#
#  add_33 (Add)                   (None, 32, 32, 853)  0           ['batch_normalization_181[0][0]',
#                                                                   'batch_normalization_185[0][0]']
#
#  batch_normalization_175 (Batch  (None, 64, 64, 256)  768        ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_176[0][0]']
#
#  activation_138 (Activation)    (None, 32, 32, 853)  0           ['add_33[0][0]']
#
#  add_32 (Add)                   (None, 64, 64, 256)  0           ['batch_normalization_175[0][0]',
#                                                                   'activation_130[0][0]']
#
#  batch_normalization_186 (Batch  (None, 32, 32, 853)  3412       ['activation_138[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 64, 64, 256)  0           ['add_32[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 256)  873728     ['batch_normalization_186[0][0]']
#  spose)
#
#  batch_normalization_177 (Batch  (None, 64, 64, 256)  1024       ['activation_131[0][0]']
#  Normalization)
#
#  concatenate_32 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'batch_normalization_177[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 64, 64, 71)   327168      ['concatenate_32[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 64, 64, 71)   327168      ['concatenate_32[0][0]']
#
#  batch_normalization_187 (Batch  (None, 64, 64, 71)  213         ['conv2d_125[0][0]']
#  Normalization)
#
#  batch_normalization_191 (Batch  (None, 64, 64, 71)  213         ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 64, 64, 71)   0           ['batch_normalization_187[0][0]']
#
#  activation_142 (Activation)    (None, 64, 64, 71)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 64, 64, 142)  90738       ['activation_139[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 64, 64, 142)  90738       ['activation_142[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 128, 128, 12  244224      ['batch_normalization_159[0][0]']
#                                 8)
#
#  batch_normalization_188 (Batch  (None, 64, 64, 142)  426        ['conv2d_126[0][0]']
#  Normalization)
#
#  batch_normalization_192 (Batch  (None, 64, 64, 142)  426        ['conv2d_129[0][0]']
#  Normalization)
#
#  conv2d_107 (Conv2D)            (None, 128, 128, 12  27136       ['batch_normalization_159[0][0]']
#                                 8)
#
#  batch_normalization_161 (Batch  (None, 128, 128, 12  384        ['conv2d_108[0][0]']
#  Normalization)                 8)
#
#  activation_140 (Activation)    (None, 64, 64, 142)  0           ['batch_normalization_188[0][0]']
#
#  activation_143 (Activation)    (None, 64, 64, 142)  0           ['batch_normalization_192[0][0]']
#
#  batch_normalization_160 (Batch  (None, 128, 128, 12  384        ['conv2d_107[0][0]']
#  Normalization)                 8)
#
#  activation_119 (Activation)    (None, 128, 128, 12  0           ['batch_normalization_161[0][0]']
#                                 8)
#
#  conv2d_127 (Conv2D)            (None, 64, 64, 213)  272214      ['activation_140[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 64, 64, 213)  272214      ['activation_143[0][0]']
#
#  add_29 (Add)                   (None, 128, 128, 12  0           ['batch_normalization_160[0][0]',
#                                 8)                                'activation_119[0][0]']
#
#  batch_normalization_189 (Batch  (None, 64, 64, 213)  639        ['conv2d_127[0][0]']
#  Normalization)
#
#  batch_normalization_193 (Batch  (None, 64, 64, 213)  639        ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 128, 128, 12  0           ['add_29[0][0]']
#                                 8)
#
#  activation_141 (Activation)    (None, 64, 64, 213)  0           ['batch_normalization_189[0][0]']
#
#  activation_144 (Activation)    (None, 64, 64, 213)  0           ['batch_normalization_193[0][0]']
#
#  batch_normalization_162 (Batch  (None, 128, 128, 12  512        ['activation_120[0][0]']
#  Normalization)                 8)
#
#  concatenate_33 (Concatenate)   (None, 64, 64, 426)  0           ['activation_139[0][0]',
#                                                                   'activation_140[0][0]',
#                                                                   'activation_141[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 64, 64, 426)  0           ['activation_142[0][0]',
#                                                                   'activation_143[0][0]',
#                                                                   'activation_144[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 128, 128, 12  147456      ['batch_normalization_162[0][0]']
#                                 8)
#
#  batch_normalization_190 (Batch  (None, 64, 64, 426)  1704       ['concatenate_33[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 64, 64, 426)  1704       ['concatenate_34[0][0]']
#  Normalization)
#
#  conv2d_109 (Conv2D)            (None, 128, 128, 12  16384       ['batch_normalization_162[0][0]']
#                                 8)
#
#  batch_normalization_164 (Batch  (None, 128, 128, 12  384        ['conv2d_110[0][0]']
# ...
#
#  conv2d_142 (Conv2D)            (None, 256, 256, 53  16695       ['activation_157[0][0]']
#                                 )
#
#  add_22 (Add)                   (None, 512, 512, 32  0           ['batch_normalization_127[0][0]',
#                                 )                                 'activation_95[0][0]']
#
#  batch_normalization_207 (Batch  (None, 256, 256, 53  159        ['conv2d_139[0][0]']
#  Normalization)                 )
#
#  batch_normalization_211 (Batch  (None, 256, 256, 53  159        ['conv2d_142[0][0]']
#  Normalization)                 )
#
#  activation_96 (Activation)     (None, 512, 512, 32  0           ['add_22[0][0]']
#                                 )
#
#  activation_155 (Activation)    (None, 256, 256, 53  0           ['batch_normalization_207[0][0]']
#                                 )
#
#  activation_158 (Activation)    (None, 256, 256, 53  0           ['batch_normalization_211[0][0]']
#                                 )
#
#  batch_normalization_129 (Batch  (None, 512, 512, 32  128        ['activation_96[0][0]']
#  Normalization)                 )
#
#  concatenate_39 (Concatenate)   (None, 256, 256, 10  0           ['activation_153[0][0]',
#                                 5)                                'activation_154[0][0]',
#                                                                   'activation_155[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 256, 256, 10  0           ['activation_156[0][0]',
#                                 5)                                'activation_157[0][0]',
#                                                                   'activation_158[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 512, 512, 32  9216        ['batch_normalization_129[0][0]']
#                                 )
#
#  batch_normalization_208 (Batch  (None, 256, 256, 10  420        ['concatenate_39[0][0]']
#  Normalization)                 5)
#
#  batch_normalization_212 (Batch  (None, 256, 256, 10  420        ['concatenate_40[0][0]']
#  Normalization)                 5)
#
#  conv2d_87 (Conv2D)             (None, 512, 512, 32  1024        ['batch_normalization_129[0][0]']
#                                 )
#
#  batch_normalization_131 (Batch  (None, 512, 512, 32  96         ['conv2d_88[0][0]']
#  Normalization)                 )
#
#  add_36 (Add)                   (None, 256, 256, 10  0           ['batch_normalization_208[0][0]',
#                                 5)                                'batch_normalization_212[0][0]']
#
#  batch_normalization_130 (Batch  (None, 512, 512, 32  96         ['conv2d_87[0][0]']
#  Normalization)                 )
#
#  activation_97 (Activation)     (None, 512, 512, 32  0           ['batch_normalization_131[0][0]']
#                                 )
#
#  activation_159 (Activation)    (None, 256, 256, 10  0           ['add_36[0][0]']
#                                 5)
#
#  add_23 (Add)                   (None, 512, 512, 32  0           ['batch_normalization_130[0][0]',
#                                 )                                 'activation_97[0][0]']
#
#  batch_normalization_213 (Batch  (None, 256, 256, 10  420        ['activation_159[0][0]']
#  Normalization)                 5)
#
#  activation_98 (Activation)     (None, 512, 512, 32  0           ['add_23[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 32  13472      ['batch_normalization_213[0][0]']
#  spose)                         )
#
#  batch_normalization_132 (Batch  (None, 512, 512, 32  128        ['activation_98[0][0]']
#  Normalization)                 )
#
#  concatenate_41 (Concatenate)   (None, 512, 512, 64  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'batch_normalization_132[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 512, 512, 8)  4608        ['concatenate_41[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 512, 512, 8)  4608        ['concatenate_41[0][0]']
#
#  batch_normalization_214 (Batch  (None, 512, 512, 8)  24         ['conv2d_143[0][0]']
#  Normalization)
#
#  batch_normalization_218 (Batch  (None, 512, 512, 8)  24         ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_160 (Activation)    (None, 512, 512, 8)  0           ['batch_normalization_214[0][0]']
#
#  activation_163 (Activation)    (None, 512, 512, 8)  0           ['batch_normalization_218[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 512, 512, 17  1224        ['activation_160[0][0]']
#                                 )
#
#  conv2d_147 (Conv2D)            (None, 512, 512, 17  1224        ['activation_163[0][0]']
#                                 )
#
#  batch_normalization_215 (Batch  (None, 512, 512, 17  51         ['conv2d_144[0][0]']
#  Normalization)                 )
#
#  batch_normalization_219 (Batch  (None, 512, 512, 17  51         ['conv2d_147[0][0]']
#  Normalization)                 )
#
#  activation_161 (Activation)    (None, 512, 512, 17  0           ['batch_normalization_215[0][0]']
#                                 )
#
#  activation_164 (Activation)    (None, 512, 512, 17  0           ['batch_normalization_219[0][0]']
#                                 )
#
#  conv2d_145 (Conv2D)            (None, 512, 512, 26  3978        ['activation_161[0][0]']
#                                 )
#
#  conv2d_148 (Conv2D)            (None, 512, 512, 26  3978        ['activation_164[0][0]']
#                                 )
#
#  batch_normalization_216 (Batch  (None, 512, 512, 26  78         ['conv2d_145[0][0]']
#  Normalization)                 )
#
#  batch_normalization_220 (Batch  (None, 512, 512, 26  78         ['conv2d_148[0][0]']
#  Normalization)                 )
#
#  activation_162 (Activation)    (None, 512, 512, 26  0           ['batch_normalization_216[0][0]']
#                                 )
#
#  activation_165 (Activation)    (None, 512, 512, 26  0           ['batch_normalization_220[0][0]']
#                                 )
#
#  concatenate_42 (Concatenate)   (None, 512, 512, 51  0           ['activation_160[0][0]',
#                                 )                                 'activation_161[0][0]',
#                                                                   'activation_162[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 512, 512, 51  0           ['activation_163[0][0]',
#                                 )                                 'activation_164[0][0]',
#                                                                   'activation_165[0][0]']
#
#  batch_normalization_217 (Batch  (None, 512, 512, 51  204        ['concatenate_42[0][0]']
#  Normalization)                 )
#
#  batch_normalization_221 (Batch  (None, 512, 512, 51  204        ['concatenate_43[0][0]']
#  Normalization)                 )
#
#  add_37 (Add)                   (None, 512, 512, 51  0           ['batch_normalization_217[0][0]',
#                                 )                                 'batch_normalization_221[0][0]']
#
#  activation_166 (Activation)    (None, 512, 512, 51  0           ['add_37[0][0]']
#                                 )
#
#  batch_normalization_222 (Batch  (None, 512, 512, 51  204        ['activation_166[0][0]']
#  Normalization)                 )
#
#  conv2d_149 (Conv2D)            (None, 512, 512, 3)  153         ['batch_normalization_222[0][0]']
#
#  batch_normalization_223 (Batch  (None, 512, 512, 3)  9          ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_167 (Activation)    (None, 512, 512, 3)  0           ['batch_normalization_223[0][0]']
#
# ==================================================================================================
# Total params: 10,070,036
# Trainable params: 10,040,628
# Non-trainable params: 29,408
# __________________________________________________________________________________________________

# %%
image_path = '/content/drive/MyDrive/source2'
models_path = '/content/drive/MyDrive/models/'

# %%
import itertools
import tensorflow as tf
from speedup import generate_out_images3
import numpy as np
from random import randint, uniform
import imageio
import time


source_num = 2799
dim = 512
stationary_defocus = 0.05


def gen():
    while True:
        layer1_number = randint(0, source_num)
        layer2_number = randint(0, source_num)
        layer3_number = randint(0, source_num)

        src1 = imageio.imread(image_path + '/image' + str(layer1_number).zfill(4) + '.png')
        src2 = imageio.imread(image_path + '/image' + str(layer2_number).zfill(4) + '.png')
        src3 = imageio.imread(image_path + '/image' + str(layer3_number).zfill(4) + '.png')
        src = np.zeros((dim, dim, m), np.double)
        src[:, :, 0] = src1[:, :, 0]
        src[:, :, 1] = src2[:, :, 0]
        src[:, :, 2] = src3[:, :, 0]
        src = src - np.amin(src)
        src = src / np.amax(src)

        w = uniform(0.05, 0.5) 
        
        a_10 = uniform(-1e3, 1e3)
        a_01 = uniform(-1e3, 1e3)
        b_20 = uniform(1, 1.5)
        b_11 = uniform(-0.1, 0.1)
        b_02 = uniform(1, 1.5)
        c_30 = uniform(-1.5e-6, 1.5e-6)
        c_21 = uniform(-2e-6, 2e-6)
        c_12 = uniform(-2e-6, 2e-6)
        c_03 = uniform(-1.5e-6, 1.5e-6)

        out = generate_out_images3(dim, m, w, stationary_defocus, a_10, a_01, b_20, b_11, b_02, c_30, c_21, c_12, c_03, src)[1]

        out = out / np.amax(out)

        src[src > 0] = 1.

        yield (out, src)


tr_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .batch(batch_size=2).prefetch(buffer_size=8)

val_dataset = tf.data.Dataset.from_generator(
     gen, (tf.float64, tf.float64), (tf.TensorShape([dim, dim, m]), tf.TensorShape([dim, dim, m])))\
    .take(count=128).cache().batch(batch_size=2)


opt = tf.keras.optimizers.Adam()

save_best_callback = tf.keras.callbacks.ModelCheckpoint(models_path + 'bestmodel_dc_unet_3params_rate.hdf5',
                                                        save_weights_only=True,save_best_only=True, verbose=True)
csv_logger_callback = tf.keras.callbacks.CSVLogger(models_path + 'log_dc_unet_3params_rate.csv')
lr_reduce_callback = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, min_delta=5e-4, patience=5)
early_stop_callback = tf.keras.callbacks.EarlyStopping(patience=25)

model_instance = constructModel()
model_instance.compile(loss='binary_crossentropy', optimizer=opt, metrics=['binary_crossentropy', 'mse'])
model_instance.fit(x=tr_dataset, validation_data=val_dataset, verbose=1, validation_steps=64,
                   steps_per_epoch=256, epochs=200,
                   callbacks=[save_best_callback, csv_logger_callback, lr_reduce_callback, early_stop_callback])
